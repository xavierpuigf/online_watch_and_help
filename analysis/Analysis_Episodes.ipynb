# %%
import pickle as pkl
import glob
from tqdm.notebook import tqdm
import numpy as np
from matplotlib import pyplot as plt
from multiprocessing import Pool
from collections import Counter

# %%
file = '../../data_scratch/train_env_task_set_20_full_reduced_tasks/6_partial_opencost0_closecostFalse_walkcost0.05_forgetrate0.2v9_particles_v2/logs_episode.247_iter.0.pik'
with open(file, 'rb') as f:
    content = pkl.load(f)

# %%
content['goals']
# Out:
# {0: {'on_cupcake_136': 1,
#   'on_juice_136': 1,
#   'on_pancake_136': 0,
#   'on_poundcake_136': 0,
#   'on_wine_136': 0,
#   'on_pudding_136': 0,
#   'on_apple_136': 1,
#   'on_coffeepot_136': 0},
#  1: {'on_cupcake_136': 1,
#   'on_juice_136': 1,
#   'on_pancake_136': 0,
#   'on_poundcake_136': 0,
#   'on_wine_136': 0,
#   'on_pudding_136': 0,
#   'on_apple_136': 1,
#   'on_coffeepot_136': 0}}

# %%
ls ../../data_scratch/large_data/train_env_task_set_20_full_reduces_tasks_single/
# Out:
# ls: cannot access '../../data_scratch/large_data/train_env_task_set_20_full_reduces_tasks_single/': No such file or directory

# %%
# data_folder = '../../data_scratch/train_env_task_set_20_full_reduced_tasks/'
#data_folder = '../../data_scratch/large_data/train_env_task_set_20_full_reduced_tasks/'
data_folder = '../../data_scratch/large_data/train_env_task_set_20_full_reduced_tasks_single/'
data_folder_test = '../../data_scratch/large_data/test_env_task_set_10_full_reduced_tasks_single/'

# %%
def get_info_file(file_name):
    with open(file_name, 'rb') as f:
        aux = pkl.load(f)
    
    if 'action' not in aux:
        print('error in', file_name)
        return {}
    num_goal_finished = sum([len(val) for key, val in aux['goals_finished'][-1].items()])
    num_goal_total = sum([val for key, val in aux['goals'][0].items()])

    length_action = len(aux['action'][0])
    data_info = {
        'length': length_action,
        'script': aux['action'],
        'finished': num_goal_finished,
        'total': num_goal_total
    }
    return data_info

def is_success(elem):
    return elem['finished'] == elem['total']

# %%
def get_info_agents(data_folder):
    agents = glob.glob('{}/*'.format(data_folder))
    agent_files = {}
    all_files = []
    for agent in agents:
        agent_name = agent.split('/')[-1]
        if agent_name[0] == 'o':
            continue
        files = [fn for fn in glob.glob('{}/*'.format(agent)) if 'results' not in fn.split('/')[-1] ]
        agent_files[agent_name] = files
        all_files += files


    print(len(all_files))

    

    data_info = {}
    with Pool(40) as p:
        info = p.map(get_info_file, all_files)
        for file_name, info_item in zip(all_files, info):
            data_info[file_name] = info_item
            
    return agent_files, data_info

# %%
def plot_info_agents(agent_files, data_info):
    agent_ids = sorted([int(agentf.split('_')[0].replace('old', ''))-1 for agentf in agent_files if agentf[0]])
    ep_gen = []
    for agent_name in sorted(agent_files.keys()):
        print(agent_name, len(agent_files[agent_name]))
        ep_gen.append(len(agent_files[agent_name]))
    fig, ax = plt.subplots()
    ax.bar(range(len(agent_ids)), ep_gen)
    ax.set_title("Episodes generated")
    ax.set_xticks(range(len(agent_ids)))
    ax.set_xticklabels(agent_ids)
    


def plot_trajectory_stats(agent_files, data_info):
    agent_ids = sorted([int(agentf.split('_')[0].replace('old', ''))-1 for agentf in agent_files if agentf[0]])

    keys = ['[walktowards]', '[open]', '[grab]', '[putback]', '[putin]']
    action_dict = {action: item for item, action in enumerate(keys)}
    nbins = 20

    success_all = []
    total_files = []
    success_mean = []
    length_mean, length_error = [], []
    action_count = []
    all_bins = []
    for agent in sorted(agent_files, key=lambda x: x.replace('old', '')):

        bins = np.zeros((len(keys), nbins))
        files = agent_files[agent]
        error_found = False
        actions_all = []
        for file in files:
            if file not in data_info:
                continue
            try:
                script = data_info[file]['script'][0]
            except:
                print(file)
            current_actions = [x.split(' ')[0].replace('>', '').replace('<', '') for x in script]
            current_action_ids = [action_dict[ca] for ca in current_actions]
            for it, cactid in enumerate(current_action_ids):
                size_bin = len(current_action_ids)/nbins
                index_bin = int(it / size_bin)
                bins[cactid, index_bin] += 1

            actions_all += current_actions

            if not is_success(data_info[file]):
                print(file)
                #for scr in script:
                #   print(scr)
                print('---')
                break
        action_count.append(Counter(actions_all))
        success = [is_success(data_info[file]) for file in files if file in data_info]
        lengths = [data_info[file]['length'] for file in files if file in data_info]
        print('{:80s} {:04d} {:.02f} {:.02f}'.format(agent, len(files), np.mean(success), np.mean(lengths)))
        success_all += success
        success_mean.append(np.mean(success))
        length_mean.append(np.mean(lengths))
        length_error.append(np.std(lengths)/np.sqrt(len(lengths)))
        all_bins.append(bins)
        
    fig, ax = plt.subplots()
    ax.bar(range(len(agent_ids)), success_mean)
    ax.set_title("Success Rate")
    ax.set_xticks(range(len(agent_ids)))
    ax.set_xticklabels(agent_ids)

    fig, ax = plt.subplots()
    try:
        ax.bar(range(len(agent_ids)), length_mean, yerr=length_error)
    except:
        print(agent_ids, length_mean)
    ax.set_title("Average Length")
    ax.set_xticks(range(len(agent_ids)))
    ax.set_xticklabels(agent_ids)

    keys = ['[walktowards]', '[open]', '[grab]', '[putback]', '[putin]']
    fig, axes = plt.subplots(1, int((1+len(action_count))), figsize=(15,2))
    print(agent_ids)
    # axes = list(axes[0]) + list(axes[1])
    for it, act in enumerate(action_count):
        values = [act[x] for x in keys]
        axes[it].pie(values)
        axes[it].set_title(agent_ids[it])
    fig.delaxes(axes[-1])

    # plt.subplot(2, (1+len(action_count))/2, len(action_count)+1)
    fig.legend(keys, loc="center right")

    for cbinid, cbin in enumerate(all_bins):
        norm_bin = cbin/cbin.sum(0)
        plt.figure(figsize=(4,4))
        for iti in range(cbin.shape[0]):
            if iti == cbin.shape[0] - 1:
                base = norm_bin[iti,:]*0
            else:
                base = norm_bin[(iti+1):,:].sum(0)
            plt.bar(range(cbin.shape[1]), norm_bin[iti,:]+base, width=1.0)
            plt.title(agent_ids[cbinid])

# %%
agent_files, data_info = get_info_agents(data_folder)
# Out:
# 7308

# %%
plot_info_agents(agent_files, data_info)
plot_trajectory_stats(agent_files, data_info)
# Out:
# 1_full_opencost0_closecostFalse_walkcost0.05_forgetrate0v9_particles_v2 3017
# 2_full_opencost0.5_closecostFalse_walkcost0.01_forgetrate0v9_particles_v2 2143
# 3_full_opencost-5_closecostFalse_walkcost0.05_forgetrate0v9_particles_v2 2148
# 1_full_opencost0_closecostFalse_walkcost0.05_forgetrate0v9_particles_v2          3017 1.00 10.52
# 2_full_opencost0.5_closecostFalse_walkcost0.01_forgetrate0v9_particles_v2        2143 1.00 10.92
# 3_full_opencost-5_closecostFalse_walkcost0.05_forgetrate0v9_particles_v2         2148 1.00 12.84
# [0, 1, 2]

# %%
agent_files, data_info = get_info_agents(data_folder_test)
plot_info_agents(agent_files, data_info)
plot_trajectory_stats(agent_files, data_info)
# Out:
# 300
# 1_full_opencost0_closecostFalse_walkcost0.05_forgetrate0v9_particles_v2 300
# 1_full_opencost0_closecostFalse_walkcost0.05_forgetrate0v9_particles_v2          0300 1.00 11.03
# [0]

# %% [markdown]
# ! rm../../data_scratch/large_data/train_env_task_set_20_full_reduced_tasks_single/3_full_opencost-5_closecostFalse_walkcost0.05_forgetrate0v9_particles_v2/results_0.pik ../../data_scratch/large_data/train_env_task_set_20_full_reduced_tasks_single/1_full_opencost0_closecostFalse_walkcost0.05_forgetrate0v9_particles_v2/results_0.pik

# %%
data_folder = '../../data_scratch/large_data/test_env_task_set_10_full_reduced_tasks/'

# %%
agent_files, data_info = get_info_agents(data_folder)
plot_info_agents(agent_files, data_info)
plot_trajectory_stats(agent_files, data_info)

# %%
rmdir ../../data_scratch/large_data/train_env_task_set_20_full_reduced_tasks_single/4_partial_opencost0_closecostFalse_walkcost0.05_forgetrate0v9_particles_v2

# %%
! rm ../../data_scratch/large_data/test_env_task_set_10_full_reduced_tasks/1_full_opencost0_closecostFalse_walkcost0.05_forgetrate0v9_particles_v2/results_0.pik

# %%
! rm ../../data_scratch/large_data/train_env_task_set_20_full_reduced_tasks_single/3_full_opencost-5_closecostFalse_walkcost0.05_forgetrate0v9_particles_v2/results_0.pik

# %%
! rm ../../data_scratch/large_data/train_env_task_set_20_full_reduced_tasks/1_full_opencost0_closecostFalse_walkcost0.05_forgetrate0v9_particles_v2/results_0.pik

# %%
print(np.mean(success_all))

# %%
sorted(agent_files)

# %%
agent_ids = sorted([int(agentf.split('_')[0].replace('old', ''))-1 for agentf in agent_files])
fig, ax = plt.subplots()
ax.bar(range(len(agent_ids)), success_mean)
ax.set_title("Success Rate")
ax.set_xticks(range(len(agent_ids)))
ax.set_xticklabels(agent_ids)

# %%
agent_ids
# Out:
# [0, 1, 2, 3, 5, 6, 7]

# %%
# agent_ids = sorted([agentf.split('_')[0] for agentf in agent_files])
fig, ax = plt.subplots()

ax.bar(range(len(agent_ids)), length_mean, yerr=length_error)
ax.set_title("Average Length")
ax.set_xticks(range(len(agent_ids)))
ax.set_xticklabels(agent_ids)
# Out:
# [Text(0, 0, '0')]

# %%
# Out:
# [0]

# %%
(1+len(action_count))/2
# Out:
# 4.5

# %%
act.keys()
# Out:
# dict_keys(['[open]', '[walktowards]', '[grab]', '[putback]', '[putin]'])

# %%
aux['graph'][0]['nodes']
# Out:
# [{'id': 1,
#   'category': 'Characters',
#   'class_name': 'character',
#   'bounding_box': {'center': [-1.56170034, 0.9229192, 2.80007076],
#    'size': [0.722174644, 1.81389093, 0.957253456]},
#   'states': []},
#  {'id': 11,
#   'category': 'Rooms',
#   'class_name': 'kitchen',
#   'bounding_box': {'center': [-3.75, 1.25, 3.75], 'size': [8.0, 3.0, 10.5]},
#   'states': []},
#  {'id': 12,
#   'category': 'Walls',
#   'class_name': 'wall',
#   'bounding_box': {'center': [-7.47, 1.24999988, 2.49999523],
#    'size': [0.06000071, 2.50000882, 2.50000954]},
#   'states': []},
#  {'id': 13,
#   'category': 'Walls',
#   'class_name': 'wall',
#   'bounding_box': {'center': [-3.74999547, 1.24999571, -1.22000134],
#    'size': [2.50001049, 2.50000954, 0.0600039065]},
#   'states': []},
#  {'id': 14,
#   'category': 'Walls',
#   'class_name': 'wall',
#   'bounding_box': {'center': [-3.75000882, 1.24999344, 8.720001],
#    'size': [2.500019, 2.50002646, 0.0599974133]},
#   'states': []},
#  {'id': 15,
#   'category': 'Walls',
#   'class_name': 'wall',
#   'bounding_box': {'center': [-1.250002, 1.25, 7.15255737e-07],
#    'size': [2.50000548, 2.500009, 2.500006]},
#   'states': []},
#  {'id': 16,
#   'category': 'Walls',
#   'class_name': 'wall',
#   'bounding_box': {'center': [-6.25, 1.25, 1.847744e-06],
#    'size': [2.50000429, 2.500009, 2.50000381]},
#   'states': []},
#  {'id': 17,
#   'category': 'Walls',
#   'class_name': 'wall',
#   'bounding_box': {'center': [-6.249998, 1.25, 7.499999],
#    'size': [2.50000548, 2.500009, 2.500006]},
#   'states': []},
#  {'id': 18,
#   'category': 'Walls',
#   'class_name': 'wall',
#   'bounding_box': {'center': [-7.47, 1.24999988, 4.999995],
#    'size': [0.06000071, 2.50000882, 2.50000954]},
#   'states': []},
#  {'id': 19,
#   'category': 'Walls',
#   'class_name': 'wall',
#   'bounding_box': {'center': [-0.03000021, 1.24999988, 5.000005],
#    'size': [0.06000071, 2.50000882, 2.50000954]},
#   'states': []},
#  {'id': 20,
#   'category': 'Walls',
#   'class_name': 'wall',
#   'bounding_box': {'center': [-0.029998634, 1.24999571, 2.50000453],
#    'size': [0.0600043871, 2.50000954, 2.500009]},
#   'states': []},
#  {'id': 21,
#   'category': 'Walls',
#   'class_name': 'wall',
#   'bounding_box': {'center': [-1.25000072, 1.2500093, 7.50001431],
#    'size': [2.50000143, 2.50002766, 2.500046]},
#   'states': []},
#  {'id': 22,
#   'category': 'Floor',
#   'class_name': 'floor',
#   'bounding_box': {'center': [-1.25, 0.0, 0.0],
#    'size': [2.5, 9.049975e-06, 2.5]},
#   'states': []},
#  {'id': 23,
#   'category': 'Floor',
#   'class_name': 'floor',
#   'bounding_box': {'center': [-3.75, 0.0, 0.0],
#    'size': [2.5, 9.049975e-06, 2.5]},
#   'states': []},
#  {'id': 24,
#   'category': 'Floor',
#   'class_name': 'floor',
#   'bounding_box': {'center': [-6.25, 0.0, 0.0],
#    'size': [2.5, 9.049975e-06, 2.5]},
#   'states': []},
#  {'id': 25,
#   'category': 'Floor',
#   'class_name': 'floor',
#   'bounding_box': {'center': [-6.25, 0.0, 2.5],
#    'size': [2.5, 9.049975e-06, 2.5]},
#   'states': []},
#  {'id': 26,
#   'category': 'Floor',
#   'class_name': 'floor',
#   'bounding_box': {'center': [-3.75, 0.0, 2.5],
#    'size': [2.5, 9.049975e-06, 2.5]},
#   'states': []},
#  {'id': 27,
#   'category': 'Floor',
#   'class_name': 'floor',
#   'bounding_box': {'center': [-1.25, 0.0, 2.5],
#    'size': [2.5, 9.049975e-06, 2.5]},
#   'states': []},
#  {'id': 28,
#   'category': 'Floor',
#   'class_name': 'floor',
#   'bounding_box': {'center': [-1.25, 0.0, 5.0],
#    'size': [2.5, 9.049975e-06, 2.5]},
#   'states': []},
#  {'id': 29,
#   'category': 'Floor',
#   'class_name': 'floor',
#   'bounding_box': {'center': [-3.75, 0.0, 5.0],
#    'size': [2.5, 9.049975e-06, 2.5]},
#   'states': []},
#  {'id': 30,
#   'category': 'Floor',
#   'class_name': 'floor',
#   'bounding_box': {'center': [-6.25, 0.0, 5.0],
#    'size': [2.5, 9.049975e-06, 2.5]},
#   'states': []},
#  {'id': 31,
#   'category': 'Floor',
#   'class_name': 'floor',
#   'bounding_box': {'center': [-6.25, 0.0, 7.5],
#    'size': [2.5, 9.049975e-06, 2.5]},
#   'states': []},
#  {'id': 32,
#   'category': 'Floor',
#   'class_name': 'floor',
#   'bounding_box': {'center': [-3.75, 0.0, 7.5],
#    'size': [2.5, 9.049975e-06, 2.5]},
#   'states': []},
#  {'id': 33,
#   'category': 'Floor',
#   'class_name': 'floor',
#   'bounding_box': {'center': [-1.25, 0.0, 7.5],
#    'size': [2.5, 9.049975e-06, 2.5]},
#   'states': []},
#  {'id': 34,
#   'category': 'Ceiling',
#   'class_name': 'ceiling',
#   'bounding_box': {'center': [-1.25, 2.50000024, -9.059906e-06],
#    'size': [2.5, 9.059906e-06, 2.5]},
#   'states': []},
#  {'id': 35,
#   'category': 'Ceiling',
#   'class_name': 'ceiling',
#   'bounding_box': {'center': [-3.75, 2.50000024, -9.059906e-06],
#    'size': [2.5, 9.059906e-06, 2.5]},
#   'states': []},
#  {'id': 36,
#   'category': 'Ceiling',
#   'class_name': 'ceiling',
#   'bounding_box': {'center': [-6.25, 2.50000024, -9.059906e-06],
#    'size': [2.5, 9.059906e-06, 2.5]},
#   'states': []},
#  {'id': 37,
#   'category': 'Ceiling',
#   'class_name': 'ceiling',
#   'bounding_box': {'center': [-6.25, 2.50000024, 2.499991],
#    'size': [2.5, 9.059906e-06, 2.5]},
#   'states': []},
#  {'id': 38,
#   'category': 'Ceiling',
#   'class_name': 'ceiling',
#   'bounding_box': {'center': [-3.75, 2.50000024, 2.499991],
#    'size': [2.5, 9.059906e-06, 2.5]},
#   'states': []},
#  {'id': 39,
#   'category': 'Ceiling',
#   'class_name': 'ceiling',
#   'bounding_box': {'center': [-1.25, 2.50000024, 2.499991],
#    'size': [2.5, 9.059906e-06, 2.5]},
#   'states': []},
#  {'id': 40,
#   'category': 'Ceiling',
#   'class_name': 'ceiling',
#   'bounding_box': {'center': [-1.25, 2.50000024, 4.999991],
#    'size': [2.5, 9.059906e-06, 2.5]},
#   'states': []},
#  {'id': 41,
#   'category': 'Ceiling',
#   'class_name': 'ceiling',
#   'bounding_box': {'center': [-3.75, 2.50000024, 4.999991],
#    'size': [2.5, 9.059906e-06, 2.5]},
#   'states': []},
#  {'id': 42,
#   'category': 'Ceiling',
#   'class_name': 'ceiling',
#   'bounding_box': {'center': [-6.25, 2.50000024, 4.999991],
#    'size': [2.5, 9.059906e-06, 2.5]},
#   'states': []},
#  {'id': 43,
#   'category': 'Ceiling',
#   'class_name': 'ceiling',
#   'bounding_box': {'center': [-6.25, 2.50000024, 7.49999046],
#    'size': [2.5, 9.059906e-06, 2.49999952]},
#   'states': []},
#  {'id': 44,
#   'category': 'Ceiling',
#   'class_name': 'ceiling',
#   'bounding_box': {'center': [-3.75, 2.50000024, 7.49999046],
#    'size': [2.5, 9.059906e-06, 2.49999952]},
#   'states': []},
#  {'id': 45,
#   'category': 'Ceiling',
#   'class_name': 'ceiling',
#   'bounding_box': {'center': [-1.25, 2.50000024, 7.49999046],
#    'size': [2.5, 9.059906e-06, 2.49999952]},
#   'states': []},
#  {'id': 46,
#   'category': 'Doors',
#   'class_name': 'doorjamb',
#   'bounding_box': {'center': [-3.75000381, 1.029126, -1.250357],
#    'size': [0.928397954, 2.058256, 0.122323215]},
#   'states': []},
#  {'id': 47,
#   'category': 'Doors',
#   'class_name': 'door',
#   'bounding_box': {'center': [0.0003574714, 0.5, 2.489997],
#    'size': [0.9283972, 1.0, 0.9283972]},
#   'states': ['OPEN']},
#  {'id': 48,
#   'category': 'Doors',
#   'class_name': 'doorjamb',
#   'bounding_box': {'center': [-1.25000393, 1.029126, 8.749643],
#    'size': [0.928397954, 2.058256, 0.122323215]},
#   'states': []},
#  {'id': 49,
#   'category': 'Windows',
#   'class_name': 'window',
#   'bounding_box': {'center': [-3.750001, 1.50000024, 8.750935],
#    'size': [2.112549, 1.02450514, 0.113748446]},
#   'states': ['CLOSED']},
#  {'id': 50,
#   'category': 'Lamps',
#   'class_name': 'ceilinglamp',
#   'bounding_box': {'center': [-3.75, 2.43006635, 0.55],
#    'size': [0.932432234, 0.152424768, 0.926426232]},
#   'states': []},
#  {'id': 51,
#   'category': 'Lamps',
#   'class_name': 'ceilinglamp',
#   'bounding_box': {'center': [-3.75, 2.43006635, 3.747],
#    'size': [0.932432234, 0.152424768, 0.926426232]},
#   'states': []},
#  {'id': 52,
#   'category': 'Lamps',
#   'class_name': 'ceilinglamp',
#   'bounding_box': {'center': [-3.75, 2.43006635, 7.248],
#    'size': [0.932432234, 0.152424768, 0.926426232]},
#   'states': []},
#  {'id': 53,
#   'category': 'Lamps',
#   'class_name': 'walllamp',
#   'bounding_box': {'center': [-7.362495, 1.51000249, 5.43304634],
#    'size': [0.0950099155, 0.121886827, 0.4781717]},
#   'states': []},
#  {'id': 54,
#   'category': 'Lamps',
#   'class_name': 'walllamp',
#   'bounding_box': {'center': [-7.362495, 1.51000249, 1.38304639],
#    'size': [0.0950099155, 0.121886827, 0.4781717]},
#   'states': []},
#  {'id': 55,
#   'category': 'Lamps',
#   'class_name': 'walllamp',
#   'bounding_box': {'center': [-7.362495, 1.51000249, 3.40304661],
#    'size': [0.0950099155, 0.121886827, 0.4781717]},
#   'states': []},
#  {'id': 56,
#   'category': 'Electronics',
#   'class_name': 'wallphone',
#   'bounding_box': {'center': [-3.104, 1.449, -1.18831968],
#    'size': [0.0933379, 0.269949377, 0.0193605814]},
#   'states': ['OFF']},
#  {'id': 57,
#   'category': 'Electronics',
#   'class_name': 'powersocket',
#   'bounding_box': {'center': [-3.19600034, 0.139, -1.19096792],
#    'size': [0.09082348, 0.154280722, 0.0160641]},
#   'states': []},
#  {'id': 58,
#   'category': 'Electronics',
#   'class_name': 'lightswitch',
#   'bounding_box': {'center': [-3.102, 1.128, -1.197448],
#    'size': [0.06867791, 0.0936371461, 0.00510568358]},
#   'states': ['ON']},
#  {'id': 59,
#   'category': 'Props',
#   'class_name': 'cutleryknife',
#   'bounding_box': {'center': [-7.43963337, 1.37204862, 2.259601],
#    'size': [0.0187248047, 0.3164823, 0.04737649]},
#   'states': []},
#  {'id': 60,
#   'category': 'Props',
#   'class_name': 'cutleryknife',
#   'bounding_box': {'center': [-7.43963337, 1.37229013, 2.37782073],
#    'size': [0.0187248047, 0.316965282, 0.0438155681]},
#   'states': []},
#  {'id': 61,
#   'category': 'Props',
#   'class_name': 'knifeblock',
#   'bounding_box': {'center': [-7.44340467, 1.4, 2.26],
#    'size': [0.0131904939, 0.0448102057, 0.5565959]},
#   'states': []},
#  {'id': 62,
#   'category': 'Props',
#   'class_name': 'fryingpan',
#   'bounding_box': {'center': [-7.12708139, 1.12977719, 3.67067456],
#    'size': [0.5962987, 0.06835502, 0.61181134]},
#   'states': []},
#  {'id': 63,
#   'category': 'Props',
#   'class_name': 'cookingpot',
#   'bounding_box': {'center': [-6.736555, 1.14742422, 3.10474873],
#    'size': [0.414359033, 0.09484844, 0.441971183]},
#   'states': ['CLOSED']},
#  {'id': 78,
#   'category': 'Props',
#   'class_name': 'cutleryknife',
#   'bounding_box': {'center': [-3.82712626, 0.98014003, 1.84261453],
#    'size': [0.25721404, 0.00569082052, 0.0194394216]},
#   'states': []},
#  {'id': 81,
#   'category': 'Props',
#   'class_name': 'cutleryknife',
#   'bounding_box': {'center': [-3.82712626, 0.98014003, 1.0176146],
#    'size': [0.25721404, 0.00569082052, 0.0194394216]},
#   'states': []},
#  {'id': 86,
#   'category': 'Props',
#   'class_name': 'cutleryknife',
#   'bounding_box': {'center': [-3.82712626, 0.98014003, 4.73361444],
#    'size': [0.25721404, 0.00569082052, 0.0194394216]},
#   'states': []},
#  {'id': 89,
#   'category': 'Props',
#   'class_name': 'cutleryknife',
#   'bounding_box': {'center': [-3.82712626, 0.98014003, 5.55861473],
#    'size': [0.25721404, 0.00569082052, 0.0194394216]},
#   'states': []},
#  {'id': 92,
#   'category': 'Props',
#   'class_name': 'condimentshaker',
#   'bounding_box': {'center': [-3.495, 1.033723, 5.375],
#    'size': [0.0497071035, 0.103446111, 0.0573968068]},
#   'states': []},
#  {'id': 93,
#   'category': 'Props',
#   'class_name': 'condimentshaker',
#   'bounding_box': {'center': [-3.496, 1.033723, 5.298],
#    'size': [0.0497071035, 0.103446111, 0.0573968068]},
#   'states': []},
#  {'id': 94,
#   'category': 'Props',
#   'class_name': 'condimentbottle',
#   'bounding_box': {'center': [-3.502, 1.08389056, 1.74499977],
#    'size': [0.0603268258, 0.203781426, 0.06032738]},
#   'states': []},
#  {'id': 95,
#   'category': 'Props',
#   'class_name': 'condimentbottle',
#   'bounding_box': {'center': [-3.496, 1.08389056, 1.4879998],
#    'size': [0.0603268258, 0.203781426, 0.06032738]},
#   'states': []},
#  {'id': 96,
#   'category': 'Props',
#   'class_name': 'condimentbottle',
#   'bounding_box': {'center': [-3.502, 1.08389056, 5.46199942],
#    'size': [0.0603268258, 0.203781426, 0.06032738]},
#   'states': []},
#  {'id': 97,
#   'category': 'Props',
#   'class_name': 'condimentbottle',
#   'bounding_box': {'center': [-3.496, 1.08389056, 5.20499945],
#    'size': [0.0603268258, 0.203781426, 0.06032738]},
#   'states': []},
#  {'id': 98,
#   'category': 'Props',
#   'class_name': 'condimentshaker',
#   'bounding_box': {'center': [-3.49542761, 1.03372312, 1.6475637],
#    'size': [0.0497071035, 0.103446111, 0.0573968068]},
#   'states': []},
#  {'id': 99,
#   'category': 'Props',
#   'class_name': 'condimentshaker',
#   'bounding_box': {'center': [-3.496, 1.033723, 1.571],
#    'size': [0.0497071035, 0.103446111, 0.0573968068]},
#   'states': []},
#  {'id': 105,
#   'category': 'Props',
#   'class_name': 'book',
#   'bounding_box': {'center': [-0.234450117, 1.79574847, -0.2558514],
#    'size': [0.187510908, 0.233031318, 0.112448946]},
#   'states': ['CLOSED']},
#  {'id': 106,
#   'category': 'Props',
#   'class_name': 'book',
#   'bounding_box': {'center': [-0.234450117, 1.79999912, -0.186861575],
#    'size': [0.187511131, 0.235479563, 0.03420768]},
#   'states': ['CLOSED']},
#  {'id': 107,
#   'category': 'Props',
#   'class_name': 'book',
#   'bounding_box': {'center': [-0.234450117, 1.80000079, -0.153138429],
#    'size': [0.187510908, 0.23547937, 0.03420718]},
#   'states': ['CLOSED']},
#  {'id': 108,
#   'category': 'Props',
#   'class_name': 'book',
#   'bounding_box': {'center': [-0.227810919, 0.6823968, 6.77791739],
#    'size': [0.302082151, 0.0454350524, 0.353066325]},
#   'states': ['CLOSED']},
#  {'id': 109,
#   'category': 'Props',
#   'class_name': 'book',
#   'bounding_box': {'center': [-0.228153855, 0.6373968, 6.77738428],
#    'size': [0.38326177, 0.0454350524, 0.3990371]},
#   'states': ['CLOSED']},
#  {'id': 110,
#   'category': 'Props',
#   'class_name': 'book',
#   'bounding_box': {'center': [-0.228434339, 0.5933968, 6.77799034],
#    'size': [0.339805037, 0.0454350524, 0.378359348]},
#   'states': ['CLOSED']},
#  {'id': 111,
#   'category': 'Props',
#   'class_name': 'photoframe',
#   'bounding_box': {'center': [-0.2394279, 1.23326325, 7.79507256],
#    'size': [0.150382221, 0.212527975, 0.173865557]},
#   'states': []},
#  {'id': 114,
#   'category': 'Props',
#   'class_name': 'box',
#   'bounding_box': {'center': [-0.209999725, 0.667310238, 0.150000036],
#    'size': [0.278566, 0.19462195, 0.404684722]},
#   'states': ['CLOSED']},
#  {'id': 115,
#   'category': 'Props',
#   'class_name': 'dishbowl',
#   'bounding_box': {'center': [-7.077, 1.20128345, -0.331000268],
#    'size': [0.273860782, 0.08116754, 0.273860782]},
#   'states': []},
#  {'id': 116,
#   'category': 'Props',
#   'class_name': 'dishbowl',
#   'bounding_box': {'center': [-7.077, 1.18088353, -0.331000268],
#    'size': [0.273860782, 0.08116754, 0.273860782]},
#   'states': []},
#  {'id': 117,
#   'category': 'Props',
#   'class_name': 'dishbowl',
#   'bounding_box': {'center': [-7.077, 1.15928352, -0.331000268],
#    'size': [0.273860782, 0.08116754, 0.273860782]},
#   'states': []},
#  {'id': 118,
#   'category': 'Props',
#   'class_name': 'dishbowl',
#   'bounding_box': {'center': [-7.077, 1.13358355, -0.331000268],
#    'size': [0.273860782, 0.08116754, 0.273860782]},
#   'states': []},
#  {'id': 119,
#   'category': 'Props',
#   'class_name': 'dishbowl',
#   'bounding_box': {'center': [-7.07701969, 1.11063182, -0.330996275],
#    'size': [0.273860782, 0.08116754, 0.273860782]},
#   'states': []},
#  {'id': 120,
#   'category': 'Props',
#   'class_name': 'cellphone',
#   'bounding_box': {'center': [-0.3009, 0.5768, 6.2239],
#    'size': [0.144601047, 0.0122878551, 0.137202263]},
#   'states': ['OFF']},
#  {'id': 121,
#   'category': 'Props',
#   'class_name': 'book',
#   'bounding_box': {'center': [-0.244950712, 0.750541, 7.83238268],
#    'size': [0.244146645, 0.3233683, 0.03543663]},
#   'states': ['CLOSED']},
#  {'id': 122,
#   'category': 'Props',
#   'class_name': 'folder',
#   'bounding_box': {'center': [-0.202999979, 0.732, 0.839],
#    'size': [0.293678939, 0.3244952, 0.2088306]},
#   'states': ['CLOSED']},
#  {'id': 123,
#   'category': 'Decor',
#   'class_name': 'rug',
#   'bounding_box': {'center': [-3.496, 0.0176881477, 1.628999],
#    'size': [2.72654963, 0.0173837226, 2.09270716]},
#   'states': []},
#  {'id': 124,
#   'category': 'Decor',
#   'class_name': 'rug',
#   'bounding_box': {'center': [-3.496, 0.0176881477, 5.322999],
#    'size': [2.72654867, 0.0173837226, 2.09270668]},
#   'states': []},
#  {'id': 125,
#   'category': 'Decor',
#   'class_name': 'candle',
#   'bounding_box': {'center': [-0.367, 0.37158078, 4.928],
#    'size': [0.0827575549, 0.137161791, 0.0827579647]},
#   'states': ['OFF']},
#  {'id': 126,
#   'category': 'Decor',
#   'class_name': 'orchid',
#   'bounding_box': {'center': [-0.3959993, 0.39599207, 4.43700027],
#    'size': [0.241401166, 0.1939848, 0.2414012]},
#   'states': []},
#  {'id': 127,
#   'category': 'Decor',
#   'class_name': 'wallpictureframe',
#   'bounding_box': {'center': [-0.0768600255, 1.31200016, 4.736001],
#    'size': [0.0417261161, 1.2570436, 0.955631256]},
#   'states': []},
#  {'id': 128,
#   'category': 'Decor',
#   'class_name': 'curtains',
#   'bounding_box': {'center': [-3.74988246, 2.06288552, 8.655561],
#    'size': [2.32801247, 0.0333948135, 0.0259935856]},
#   'states': ['CLOSED']},
#  {'id': 129,
#   'category': 'Decor',
#   'class_name': 'curtains',
#   'bounding_box': {'center': [-4.29299831, 1.50355089, 8.641396],
#    'size': [1.06320214, 1.15232825, 0.08798504]},
#   'states': ['CLOSED']},
#  {'id': 130,
#   'category': 'Decor',
#   'class_name': 'curtains',
#   'bounding_box': {'center': [-3.19499826, 1.50355089, 8.641396],
#    'size': [1.06320238, 1.15232825, 0.08798504]},
#   'states': ['CLOSED']},
#  {'id': 131,
#   'category': 'Furniture',
#   'class_name': 'bench',
#   'bounding_box': {'center': [-4.352, 0.328, 1.632],
#    'size': [0.350200027, 0.508300066, 1.57760012]},
#   'states': []},
#  {'id': 132,
#   'category': 'Furniture',
#   'class_name': 'kitchentable',
#   'bounding_box': {'center': [-3.498, 0.504, 1.632],
#    'size': [1.092, 0.950000048, 2.0]},
#   'states': []},
#  {'id': 133,
#   'category': 'Furniture',
#   'class_name': 'bench',
#   'bounding_box': {'center': [-2.688, 0.328, 1.632],
#    'size': [0.350200027, 0.508300066, 1.57760012]},
#   'states': []},
#  {'id': 134,
#   'category': 'Furniture',
#   'class_name': 'bench',
#   'bounding_box': {'center': [-2.688, 0.328, 5.318],
#    'size': [0.350200027, 0.508300066, 1.57760012]},
#   'states': []},
#  {'id': 135,
#   'category': 'Furniture',
#   'class_name': 'bench',
#   'bounding_box': {'center': [-4.352, 0.328, 5.318],
#    'size': [0.350200027, 0.508300066, 1.57760012]},
#   'states': []},
#  {'id': 136,
#   'category': 'Furniture',
#   'class_name': 'kitchentable',
#   'bounding_box': {'center': [-3.498, 0.504, 5.318],
#    'size': [1.092, 0.950000048, 2.0]},
#   'states': []},
#  {'id': 137,
#   'category': 'Furniture',
#   'class_name': 'kitchencounter',
#   'bounding_box': {'center': [-7.06100035, 0.535, -0.311000019],
#    'size': [0.770000041, 1.07, 0.316]},
#   'states': ['CLOSED']},
#  {'id': 138,
#   'category': 'Furniture',
#   'class_name': 'kitchencounter',
#   'bounding_box': {'center': [-7.054, 0.52, 5.404],
#    'size': [0.77, 1.05, 3.014]},
#   'states': ['CLOSED']},
#  {'id': 139,
#   'category': 'Furniture',
#   'class_name': 'kitchencabinet',
#   'bounding_box': {'center': [-7.238623, 2.05115032, 2.4912],
#    'size': [0.402153969, 0.6996989, 0.7580004]},
#   'states': ['CLOSED']},
#  {'id': 140,
#   'category': 'Furniture',
#   'class_name': 'kitchencabinet',
#   'bounding_box': {'center': [-7.23842335, 2.05115032, 1.7428],
#    'size': [0.402154922, 0.6996989, 0.7579999]},
#   'states': ['CLOSED']},
#  {'id': 141,
#   'category': 'Furniture',
#   'class_name': 'kitchencabinet',
#   'bounding_box': {'center': [-7.23842335, 2.05115032, 0.992199957],
#    'size': [0.402154922, 0.6996989, 0.758]},
#   'states': ['CLOSED']},
#  {'id': 142,
#   'category': 'Furniture',
#   'class_name': 'kitchencabinet',
#   'bounding_box': {'center': [-7.23842335, 2.05115032, 0.245399967],
#    'size': [0.402154922, 0.6996989, 0.758]},
#   'states': ['CLOSED']},
#  {'id': 143,
#   'category': 'Furniture',
#   'class_name': 'kitchencabinet',
#   'bounding_box': {'center': [-7.238623, 2.05115032, 6.5232],
#    'size': [0.402153969, 0.6996989, 0.7580004]},
#   'states': ['CLOSED']},
#  {'id': 144,
#   'category': 'Furniture',
#   'class_name': 'kitchencabinet',
#   'bounding_box': {'center': [-7.23842335, 2.05115032, 5.7748],
#    'size': [0.402154922, 0.6996989, 0.7580004]},
#   'states': ['CLOSED']},
#  {'id': 145,
#   'category': 'Furniture',
#   'class_name': 'kitchencabinet',
#   'bounding_box': {'center': [-7.23842335, 2.05115032, 5.0242],
#    'size': [0.402154922, 0.6996989, 0.7580004]},
#   'states': ['CLOSED']},
#  {'id': 146,
#   'category': 'Furniture',
#   'class_name': 'kitchencabinet',
#   'bounding_box': {'center': [-7.23842335, 2.05115032, 4.2774],
#    'size': [0.402154922, 0.6996989, 0.7580004]},
#   'states': ['CLOSED']},
#  {'id': 147,
#   'category': 'Furniture',
#   'class_name': 'kitchencounter',
#   'bounding_box': {'center': [-7.05699968, 0.52, 1.372],
#    'size': [0.77, 1.05, 3.014]},
#   'states': ['CLOSED']},
#  {'id': 148,
#   'category': 'Furniture',
#   'class_name': 'kitchencounterdrawer',
#   'bounding_box': {'center': [-7.03899956, 0.356, 1.372],
#    'size': [0.712, 0.272, 0.982000053]},
#   'states': []},
#  {'id': 149,
#   'category': 'Furniture',
#   'class_name': 'kitchencounterdrawer',
#   'bounding_box': {'center': [-7.03899956, 0.635, 1.372],
#    'size': [0.712, 0.272, 0.982000053]},
#   'states': []},
#  {'id': 150,
#   'category': 'Furniture',
#   'class_name': 'kitchencounterdrawer',
#   'bounding_box': {'center': [-7.03899956, 0.635, 2.3678],
#    'size': [0.712, 0.272, 0.982000053]},
#   'states': []},
#  {'id': 151,
#   'category': 'Furniture',
#   'class_name': 'kitchencounterdrawer',
#   'bounding_box': {'center': [-7.03899956, 0.356, 2.3678],
#    'size': [0.712, 0.272, 0.982000053]},
#   'states': []},
#  {'id': 152,
#   'category': 'Furniture',
#   'class_name': 'kitchencounterdrawer',
#   'bounding_box': {'center': [-7.03899956, 0.909999967, 2.368],
#    'size': [0.712, 0.272, 0.982000053]},
#   'states': []},
#  {'id': 153,
#   'category': 'Furniture',
#   'class_name': 'kitchencounterdrawer',
#   'bounding_box': {'center': [-7.03899956, 0.909999967, 0.38],
#    'size': [0.712, 0.272, 0.982000053]},
#   'states': []},
#  {'id': 154,
#   'category': 'Furniture',
#   'class_name': 'kitchencounterdrawer',
#   'bounding_box': {'center': [-7.03899956, 0.356, 0.38],
#    'size': [0.712, 0.272, 0.982000053]},
#   'states': []},
#  {'id': 155,
#   'category': 'Furniture',
#   'class_name': 'kitchencounterdrawer',
#   'bounding_box': {'center': [-7.03899956, 0.635, 0.38],
#    'size': [0.712, 0.272, 0.982000053]},
#   'states': []},
#  {'id': 156,
#   'category': 'Furniture',
#   'class_name': 'sink',
#   'bounding_box': {'center': [-6.99299955, 0.838, 1.372],
#    'size': [0.377179831, 2.220446e-18, 0.6723925]},
#   'states': []},
#  {'id': 157,
#   'category': 'Furniture',
#   'class_name': 'faucet',
#   'bounding_box': {'center': [-7.336, 1.1, 1.402],
#    'size': [0.100000381, 0.0999999046, 0.0999999046]},
#   'states': ['OFF']},
#  {'id': 158,
#   'category': 'Furniture',
#   'class_name': 'tvstand',
#   'bounding_box': {'center': [-0.341, 0.149107888, 4.654196],
#    'size': [0.4544796, 0.294215769, 1.291679]},
#   'states': []},
#  {'id': 159,
#   'category': 'Furniture',
#   'class_name': 'bookshelf',
#   'bounding_box': {'center': [-0.23, 1.108, 0.42],
#    'size': [0.320000023, 2.216, 2.114]},
#   'states': ['CLOSED']},
#  {'id': 160,
#   'category': 'Furniture',
#   'class_name': 'bookshelf',
#   'bounding_box': {'center': [-0.234, 1.108, 7.056],
#    'size': [0.320000023, 2.216, 2.114]},
#   'states': ['CLOSED']},
#  {'id': 161,
#   'category': 'Furniture',
#   'class_name': 'chair',
#   'bounding_box': {'center': [-6.96438026, 0.495000035, 8.411686],
#    'size': [0.523600042, 0.8415001, 0.401200026]},
#   'states': []},
#  {'id': 162,
#   'category': 'Appliances',
#   'class_name': 'stovefan',
#   'bounding_box': {'center': [-7.13714552, 2.0959053, 3.385993],
#    'size': [0.6212864, 0.450402617, 0.9244467]},
#   'states': []},
#  {'id': 163,
#   'category': 'Appliances',
#   'class_name': 'fridge',
#   'bounding_box': {'center': [-7.076813, 1.06257987, 7.39342833],
#    'size': [0.712165236, 2.125163, 0.889662266]},
#   'states': ['CLOSED']},
#  {'id': 164,
#   'category': 'Appliances',
#   'class_name': 'stove',
#   'bounding_box': {'center': [-7.014, 0.534999967, 3.386],
#    'size': [0.832, 1.08, 1.002]},
#   'states': ['OFF', 'CLOSED']},
#  {'id': 165,
#   'category': 'Appliances',
#   'class_name': 'oventray',
#   'bounding_box': {'center': [-6.977001, 0.550777853, 3.38600183],
#    'size': [0.617406845, 0.02155888, 0.933822632]},
#   'states': []},
#  {'id': 166,
#   'category': 'Appliances',
#   'class_name': 'dishwasher',
#   'bounding_box': {'center': [-7.06592226, 0.510003448, 5.401998],
#    'size': [0.7900868, 1.02001023, 0.967084765]},
#   'states': ['CLOSED', 'OFF']},
#  {'id': 167,
#   'category': 'Appliances',
#   'class_name': 'toaster',
#   'bounding_box': {'center': [-6.84869337, 1.17439175, 6.07642365],
#    'size': [0.3399191, 0.209531546, 0.202183723]},
#   'states': ['OFF']},
#  {'id': 168,
#   'category': 'Appliances',
#   'class_name': 'breadslice',
#   'bounding_box': {'center': [-6.85539, 1.26716411, 6.0412674],
#    'size': [0.217281923, 0.0415873453, 0.0126999915]},
#   'states': []},
#  {'id': 169,
#   'category': 'Appliances',
#   'class_name': 'breadslice',
#   'bounding_box': {'center': [-6.85539, 1.26716411, 6.11076736],
#    'size': [0.217281923, 0.0415873453, 0.0126999915]},
#   'states': []},
#  {'id': 170,
#   'category': 'Appliances',
#   'class_name': 'coffeemaker',
#   'bounding_box': {'center': [-6.881003, 1.26674974, 5.405786],
#    'size': [0.2011385, 0.35950017, 0.314508438]},
#   'states': ['OFF']},
#  {'id': 171,
#   'category': 'Appliances',
#   'class_name': 'coffeepot',
#   'bounding_box': {'center': [-6.88099957, 1.19894636, 5.484248],
#    'size': [0.179828644, 0.1318934, 0.22700119]},
#   'states': ['CLOSED']},
#  {'id': 172,
#   'category': 'Appliances',
#   'class_name': 'microwave',
#   'bounding_box': {'center': [-6.911538, 1.2461462, 0.2314461],
#    'size': [0.4308796, 0.3316934, 0.6435246]},
#   'states': ['CLOSED', 'OFF']},
#  {'id': 173,
#   'category': 'Appliances',
#   'class_name': 'dishbowl',
#   'bounding_box': {'center': [-6.846694, 1.24460089, 0.17488952],
#    'size': [0.268359, 0.0584743433, 0.268404663]},
#   'states': []},
#  {'id': 174,
#   'category': 'Food',
#   'class_name': 'juice',
#   'bounding_box': {'center': [-3.43837166, 1.10889924, 4.61918354],
#    'size': [0.0794259757, 0.2537988, 0.07840236]},
#   'states': []},
#  {'id': 175,
#   'category': 'Food',
#   'class_name': 'juice',
#   'bounding_box': {'center': [-3.51970339, 1.10889924, 2.27099943],
#    'size': [0.0794259757, 0.2537988, 0.07840236]},
#   'states': []},
#  {'id': 176,
#   'category': 'Food',
#   'class_name': 'cutlets',
#   'bounding_box': {'center': [-6.82688046, 1.44880974, 0.204999834],
#    'size': [0.185793728, 0.06162097, 0.310194135]},
#   'states': []},
#  {'id': 177,
#   'category': 'Food',
#   'class_name': 'milk',
#   'bounding_box': {'center': [-7.106678, 1.1904273, 0.6505828],
#    'size': [0.123024, 0.240758, 0.123025]},
#   'states': ['CLOSED']},
#  {'id': 178,
#   'category': 'Food',
#   'class_name': 'milk',
#   'bounding_box': {'center': [-6.903, 1.1904273, 0.747999549],
#    'size': [0.123024, 0.240758, 0.123025]},
#   'states': ['CLOSED']},
#  {'id': 179,
#   'category': 'Food',
#   'class_name': 'bananas',
#   'bounding_box': {'center': [-7.07564926, 1.123359, 4.254139],
#    'size': [0.226779461, 0.100509167, 0.281417847]},
#   'states': []},
#  {'id': 180,
#   'category': 'Food',
#   'class_name': 'bananas',
#   'bounding_box': {'center': [-6.996954, 1.16602349, 4.225032],
#    'size': [0.29961586, 0.1495223, 0.262237549]},
#   'states': []},
#  {'id': 181,
#   'category': 'Food',
#   'class_name': 'dishbowl',
#   'bounding_box': {'center': [-7.03578663, 1.11387622, 4.24925661],
#    'size': [0.3566913, 0.08779088, 0.3566913]},
#   'states': []},
#  {'id': 182,
#   'category': 'Food',
#   'class_name': 'salmon',
#   'bounding_box': {'center': [-6.98207951, 1.09501672, 2.38112044],
#    'size': [0.2388873, 0.0480879024, 0.287590384]},
#   'states': []},
#  {'id': 183,
#   'category': 'Food',
#   'class_name': 'mincedmeat',
#   'bounding_box': {'center': [-6.951355, 1.09398973, 2.068238],
#    'size': [0.148635, 0.0460341, 0.248155192]},
#   'states': []},
#  {'id': 184,
#   'category': 'Rooms',
#   'class_name': 'livingroom',
#   'bounding_box': {'center': [-6.22799969, 1.25, -3.75000024],
#    'size': [8.0, 3.0, 5.5]},
#   'states': []},
#  {'id': 185,
#   'category': 'Floor',
#   'class_name': 'floor',
#   'bounding_box': {'center': [-3.72799969, 0.0, -5.0],
#    'size': [2.5, 9.049975e-06, 2.50000024]},
#   'states': []},
#  {'id': 186,
#   'category': 'Floor',
#   'class_name': 'floor',
#   'bounding_box': {'center': [-8.728, 0.0, -5.00000048],
#    'size': [2.5, 9.049975e-06, 2.50000024]},
#   'states': []},
#  {'id': 187,
#   'category': 'Floor',
#   'class_name': 'floor',
#   'bounding_box': {'center': [-8.728, 0.0, -2.500001],
#    'size': [2.5, 9.049975e-06, 2.5]},
#   'states': []},
#  {'id': 188,
#   'category': 'Floor',
#   'class_name': 'floor',
#   'bounding_box': {'center': [-3.72800016, 0.0, -2.50000024],
#    'size': [2.50000024, 9.049975e-06, 2.5]},
#   'states': []},
#  {'id': 189,
#   'category': 'Floor',
#   'class_name': 'floor',
#   'bounding_box': {'center': [-6.22799969, 0.0, -2.50000048],
#    'size': [2.5, 9.049975e-06, 2.5]},
#   'states': []},
#  {'id': 190,
#   'category': 'Floor',
#   'class_name': 'floor',
#   'bounding_box': {'center': [-6.22799969, 0.0, -5.0],
#    'size': [2.5, 9.049975e-06, 2.5]},
#   'states': []},
#  {'id': 191,
#   'category': 'Walls',
#   'class_name': 'wall',
#   'bounding_box': {'center': [-3.72750163, 1.25, -4.99989939],
#    'size': [2.50000334, 2.500009, 2.50000381]},
#   'states': []},
#  {'id': 192,
#   'category': 'Walls',
#   'class_name': 'wall',
#   'bounding_box': {'center': [-8.727588, 1.25001, -4.99988842],
#    'size': [2.50000429, 2.500009, 2.50000381]},
#   'states': []},
#  {'id': 193,
#   'category': 'Walls',
#   'class_name': 'wall',
#   'bounding_box': {'center': [-3.7275002, 1.2500093, -2.499887],
#    'size': [2.50000143, 2.50002766, 2.500046]},
#   'states': []},
#  {'id': 194,
#   'category': 'Walls',
#   'class_name': 'wall',
#   'bounding_box': {'center': [-6.227504, 1.24999988, -1.279902],
#    'size': [2.50000882, 2.50000882, 0.06000099]},
#   'states': []},
#  {'id': 195,
#   'category': 'Walls',
#   'class_name': 'wall',
#   'bounding_box': {'center': [-6.22748947, 1.24999344, -6.21990061],
#    'size': [2.500017, 2.50002646, 0.0599973574]},
#   'states': []},
#  {'id': 196,
#   'category': 'Walls',
#   'class_name': 'wall',
#   'bounding_box': {'center': [-8.727537, 1.24999428, -2.49991131],
#    'size': [2.500045, 2.50002766, 2.50000048]},
#   'states': []},
#  {'id': 197,
#   'category': 'Ceiling',
#   'class_name': 'ceiling',
#   'bounding_box': {'center': [-3.72799063, 2.50000024, -5.0],
#    'size': [2.5, 9.059906e-06, 2.50000024]},
#   'states': []},
#  {'id': 198,
#   'category': 'Ceiling',
#   'class_name': 'ceiling',
#   'bounding_box': {'center': [-3.727991, 2.50000024, -2.50000024],
#    'size': [2.50000024, 9.059906e-06, 2.5]},
#   'states': []},
#  {'id': 199,
#   'category': 'Ceiling',
#   'class_name': 'ceiling',
#   'bounding_box': {'center': [-6.22799, 2.50000024, -2.50000048],
#    'size': [2.50000048, 9.059906e-06, 2.5]},
#   'states': []},
#  {'id': 200,
#   'category': 'Ceiling',
#   'class_name': 'ceiling',
#   'bounding_box': {'center': [-6.22799, 2.50000024, -5.0],
#    'size': [2.50000048, 9.059906e-06, 2.5]},
#   'states': []},
#  {'id': 201,
#   'category': 'Ceiling',
#   'class_name': 'ceiling',
#   'bounding_box': {'center': [-8.72799, 2.50000024, -5.00000048],
#    'size': [2.5, 9.059906e-06, 2.50000024]},
#   'states': []},
#  {'id': 202,
#   'category': 'Ceiling',
#   'class_name': 'ceiling',
#   'bounding_box': {'center': [-8.72799, 2.50000024, -2.500001],
#    'size': [2.5, 9.059906e-06, 2.5]},
#   'states': []},
#  {'id': 203,
#   'category': 'Windows',
#   'class_name': 'window',
#   'bounding_box': {'center': [-6.227998, 1.50000024, -6.24993324],
#    'size': [2.11254716, 1.02450514, 0.113748342]},
#   'states': ['CLOSED']},
#  {'id': 204,
#   'category': 'Doors',
#   'class_name': 'doorjamb',
#   'bounding_box': {'center': [-9.97764, 1.029126, -2.50000525],
#    'size': [0.122323029, 2.058256, 0.9283974]},
#   'states': []},
#  {'id': 205,
#   'category': 'Lamps',
#   'class_name': 'walllamp',
#   'bounding_box': {'center': [-2.58278, 1.51175642, -2.21499753],
#    'size': [0.1115582, 0.561456263, 0.143116161]},
#   'states': []},
#  {'id': 206,
#   'category': 'Lamps',
#   'class_name': 'walllamp',
#   'bounding_box': {'center': [-2.58278, 1.51175642, -5.265996],
#    'size': [0.1115582, 0.561456263, 0.143116161]},
#   'states': []},
#  {'id': 207,
#   'category': 'Lamps',
#   'class_name': 'ceilinglamp',
#   'bounding_box': {'center': [-7.72799873, 2.43868661, -3.75000072],
#    'size': [0.7280389, 0.119784132, 0.7327586]},
#   'states': []},
#  {'id': 208,
#   'category': 'Furniture',
#   'class_name': 'tvstand',
#   'bounding_box': {'center': [-2.979, 0.246, -3.75199986],
#    'size': [0.759996355, 0.492, 2.16000128]},
#   'states': []},
#  {'id': 209,
#   'category': 'Furniture',
#   'class_name': 'wallshelf',
#   'bounding_box': {'center': [-3.72799969, 0.7893659, -6.065],
#    'size': [0.9999999, 0.1819556, 0.272273123]},
#   'states': []},
#  {'id': 210,
#   'category': 'Furniture',
#   'class_name': 'bookshelf',
#   'bounding_box': {'center': [-8.092998, 1.108, -1.48600149],
#    'size': [2.11399937, 2.216, 0.3199997]},
#   'states': ['CLOSED']},
#  {'id': 211,
#   'category': 'Furniture',
#   'class_name': 'bookshelf',
#   'bounding_box': {'center': [-5.95999861, 1.108, -1.486002],
#    'size': [2.11399937, 2.216, 0.3199997]},
#   'states': ['CLOSED']},
#  {'id': 212,
#   'category': 'Furniture',
#   'class_name': 'wallshelf',
#   'bounding_box': {'center': [-3.72799969, 1.201366, -6.065],
#    'size': [0.9999999, 0.1819556, 0.272273123]},
#   'states': []},
#  {'id': 213,
#   'category': 'Furniture',
#   'class_name': 'wallshelf',
#   'bounding_box': {'center': [-3.72799969, 1.605366, -6.065],
#    'size': [0.9999999, 0.1819556, 0.272273123]},
#   'states': []},
#  {'id': 214,
#   'category': 'Furniture',
#   'class_name': 'sofa',
#   'bounding_box': {'center': [-9.245998, 0.57100004, -4.55500031],
#    'size': [1.03869951, 0.9707001, 2.36469936]},
#   'states': []},
#  {'id': 215,
#   'category': 'Furniture',
#   'class_name': 'coffeetable',
#   'bounding_box': {'center': [-7.358718, 0.192958087, -4.47336769],
#    'size': [0.7138687, 0.3952366, 1.50079918]},
#   'states': []},
#  {'id': 216,
#   'category': 'Decor',
#   'class_name': 'candle',
#   'bounding_box': {'center': [-4.07809973, 1.76738071, -6.053999],
#    'size': [0.08275795, 0.137161791, 0.08275754]},
#   'states': ['OFF']},
#  {'id': 217,
#   'category': 'Decor',
#   'class_name': 'pillow',
#   'bounding_box': {'center': [-9.016725, 0.701504, -3.518738],
#    'size': [0.781701744, 0.371934354, 0.6913882]},
#   'states': []},
#  {'id': 218,
#   'category': 'Decor',
#   'class_name': 'wallpictureframe',
#   'bounding_box': {'center': [-9.915998, 1.74399972, -4.565],
#    'size': [0.0280017853, 0.64139986, 1.49474049]},
#   'states': []},
#  {'id': 219,
#   'category': 'Decor',
#   'class_name': 'curtains',
#   'bounding_box': {'center': [-6.228116, 2.02288556, -6.15256],
#    'size': [2.32801032, 0.0333948135, 0.0259931087]},
#   'states': ['CLOSED']},
#  {'id': 220,
#   'category': 'Decor',
#   'class_name': 'curtains',
#   'bounding_box': {'center': [-5.44099045, 1.46254826, -6.12401],
#    'size': [0.5931835, 1.15232611, 0.107337952]},
#   'states': ['CLOSED']},
#  {'id': 221,
#   'category': 'Decor',
#   'class_name': 'curtains',
#   'bounding_box': {'center': [-7.00400066, 1.46254838, -6.12700844],
#    'size': [0.5931835, 1.15232587, 0.107337952]},
#   'states': ['CLOSED']},
#  {'id': 222,
#   'category': 'Decor',
#   'class_name': 'orchid',
#   'bounding_box': {'center': [-7.341872, 0.4914499, -4.09645462],
#    'size': [0.242352009, 0.193984777, 0.242352009]},
#   'states': []},
#  {'id': 223,
#   'category': 'Decor',
#   'class_name': 'rug',
#   'bounding_box': {'center': [-5.148, 0.0069701, -3.75000024],
#    'size': [1.69976425, 0.0139463525, 1.69976473]},
#   'states': []},
#  {'id': 224,
#   'category': 'Props',
#   'class_name': 'book',
#   'bounding_box': {'center': [-7.11678362, 1.21128082, -1.44017],
#    'size': [0.028664751, 0.23956, 0.16271992]},
#   'states': ['CLOSED']},
#  {'id': 225,
#   'category': 'Props',
#   'class_name': 'cupcake',
#   'bounding_box': {'center': [-7.31599855, 0.455713421, -4.73900032],
#    'size': [0.133786529, 0.111071624, 0.133786663]},
#   'states': []},
#  {'id': 226,
#   'category': 'Props',
#   'class_name': 'cupcake',
#   'bounding_box': {'center': [-7.426997, 0.455713421, -4.769],
#    'size': [0.124435835, 0.111071624, 0.124436021]},
#   'states': []},
#  {'id': 227,
#   'category': 'Props',
#   'class_name': 'cupcake',
#   'bounding_box': {'center': [-7.403998, 0.455713421, -4.66100025],
#    'size': [0.10190621, 0.111071624, 0.101905949]},
#   'states': []},
#  {'id': 229,
#   'category': 'Props',
#   'class_name': 'book',
#   'bounding_box': {'center': [-3.727911, 1.33318293, -6.058071],
#    'size': [0.26480028, 0.07851405, 0.223381877]},
#   'states': ['CLOSED']},
#  {'id': 230,
#   'category': 'Props',
#   'class_name': 'book',
#   'bounding_box': {'center': [-3.49706483, 1.3124789, -6.049191],
#    'size': [0.302369416, 0.04032805, 0.25309056]},
#   'states': ['CLOSED']},
#  {'id': 231,
#   'category': 'Props',
#   'class_name': 'box',
#   'bounding_box': {'center': [-3.40199971, 0.93741107, -6.061099],
#    'size': [0.274631679, 0.113423072, 0.227627188]},
#   'states': ['CLOSED']},
#  {'id': 232,
#   'category': 'Props',
#   'class_name': 'photoframe',
#   'bounding_box': {'center': [-4.09537745, 0.9862633, -6.03141451],
#    'size': [0.174534544, 0.212528616, 0.129299343]},
#   'states': []},
#  {'id': 234,
#   'category': 'Props',
#   'class_name': 'book',
#   'bounding_box': {'center': [-7.78418255, 1.14045811, -1.46716928],
#    'size': [0.228959918, 0.0350424349, 0.155519992]},
#   'states': ['CLOSED']},
#  {'id': 235,
#   'category': 'Props',
#   'class_name': 'book',
#   'bounding_box': {'center': [-5.49178457, 0.705798149, -1.47117],
#    'size': [0.0336885452, 0.2794459, 0.183140278]},
#   'states': ['CLOSED']},
#  {'id': 236,
#   'category': 'Props',
#   'class_name': 'book',
#   'bounding_box': {'center': [-6.02278471, 0.727458, -1.50116968],
#    'size': [0.09213066, 0.280239582, 0.183140278]},
#   'states': ['CLOSED']},
#  {'id': 237,
#   'category': 'Props',
#   'class_name': 'slippers',
#   'bounding_box': {'center': [-5.669972, 0.109364629, -1.5343771],
#    'size': [0.368448257, 0.07181433, 0.321501255]},
#   'states': []},
#  {'id': 238,
#   'category': 'Electronics',
#   'class_name': 'tv',
#   'bounding_box': {'center': [-2.99900031, 0.9734849, -3.749998],
#    'size': [0.271927655, 0.9509725, 1.27761066]},
#   'states': ['OFF']},
#  {'id': 239,
#   'category': 'Electronics',
#   'class_name': 'lightswitch',
#   'bounding_box': {'center': [-4.3205, 1.2273, -1.30255318],
#    'size': [0.06867787, 0.0936371461, 0.00510600628]},
#   'states': ['ON']},
#  {'id': 240,
#   'category': 'Electronics',
#   'class_name': 'powersocket',
#   'bounding_box': {'center': [-4.3081007, 0.146870852, -1.308027],
#    'size': [0.09082348, 0.154280722, 0.0160645172]},
#   'states': []},
#  {'id': 241,
#   'category': 'Rooms',
#   'class_name': 'bedroom',
#   'bounding_box': {'center': [-12.4775, 1.25, -1.2935],
#    'size': [5.5, 3.0, 5.5]},
#   'states': []},
#  {'id': 242,
#   'category': 'Floor',
#   'class_name': 'floor',
#   'bounding_box': {'center': [-13.7275, 0.0, -0.0434999466],
#    'size': [2.5, 9.049975e-06, 2.5]},
#   'states': []},
#  {'id': 243,
#   'category': 'Floor',
#   'class_name': 'floor',
#   'bounding_box': {'center': [-11.2275, 0.0, -0.0434999466],
#    'size': [2.5, 9.049975e-06, 2.5]},
#   'states': []},
#  {'id': 244,
#   'category': 'Floor',
#   'class_name': 'floor',
#   'bounding_box': {'center': [-11.2275, 0.0, -2.5435],
#    'size': [2.5, 9.049975e-06, 2.5]},
#   'states': []},
#  {'id': 245,
#   'category': 'Floor',
#   'class_name': 'floor',
#   'bounding_box': {'center': [-13.7275, 0.0, -2.5435],
#    'size': [2.5, 9.049975e-06, 2.5]},
#   'states': []},
#  {'id': 246,
#   'category': 'Ceiling',
#   'class_name': 'ceiling',
#   'bounding_box': {'center': [-13.7275, 2.50000024, -0.0435090065],
#    'size': [2.5, 9.059906e-06, 2.5]},
#   'states': []},
#  {'id': 247,
#   'category': 'Ceiling',
#   'class_name': 'ceiling',
#   'bounding_box': {'center': [-11.2275, 2.50000024, -0.0435090065],
#    'size': [2.5, 9.059906e-06, 2.5]},
#   'states': []},
#  {'id': 248,
#   'category': 'Ceiling',
#   'class_name': 'ceiling',
#   'bounding_box': {'center': [-11.2275, 2.50000024, -2.543509],
#    'size': [2.5, 9.059906e-06, 2.5]},
#   'states': []},
#  {'id': 249,
#   'category': 'Ceiling',
#   'class_name': 'ceiling',
#   'bounding_box': {'center': [-13.7275, 2.50000024, -2.543509],
#    'size': [2.5, 9.059906e-06, 2.5]},
#   'states': []},
#  {'id': 250,
#   'category': 'Walls',
#   'class_name': 'wall',
#   'bounding_box': {'center': [-13.7275, 1.25, -2.543498],
#    'size': [2.50000429, 2.500009, 2.50000381]},
#   'states': []},
#  {'id': 251,
#   'category': 'Walls',
#   'class_name': 'wall',
#   'bounding_box': {'center': [-11.2275, 1.25, -0.0435018465],
#    'size': [2.50000429, 2.500009, 2.50000381]},
#   'states': []},
#  {'id': 252,
#   'category': 'Walls',
#   'class_name': 'wall',
#   'bounding_box': {'center': [-11.2274866, 1.2500093, -2.54349971],
#    'size': [2.500047, 2.50002766, 2.50000238]},
#   'states': []},
#  {'id': 253,
#   'category': 'Walls',
#   'class_name': 'wall',
#   'bounding_box': {'center': [-13.7274981, 1.25, -0.04349959],
#    'size': [2.50000334, 2.500009, 2.50000381]},
#   'states': []},
#  {'id': 254,
#   'category': 'Doors',
#   'class_name': 'door',
#   'bounding_box': {'center': [-9.977642, 0.5, -2.50000477],
#    'size': [0.9283972, 1.0, 0.9283972]},
#   'states': ['OPEN']},
#  {'id': 255,
#   'category': 'Lamps',
#   'class_name': 'ceilinglamp',
#   'bounding_box': {'center': [-12.4775, 2.22767544, -1.2935],
#    'size': [0.5316601, 0.5451052, 0.531659365]},
#   'states': []},
#  {'id': 256,
#   'category': 'Lamps',
#   'class_name': 'tablelamp',
#   'bounding_box': {'center': [-14.41998, 0.777596831, -1.13537621],
#    'size': [0.356643677, 0.5775015, 0.3455227]},
#   'states': ['ON']},
#  {'id': 257,
#   'category': 'Decor',
#   'class_name': 'rug',
#   'bounding_box': {'center': [-12.8075, 0.0069701, -0.4645],
#    'size': [1.69976425, 0.0139463525, 1.69976461]},
#   'states': []},
#  {'id': 258,
#   'category': 'Decor',
#   'class_name': 'wallpictureframe',
#   'bounding_box': {'center': [-12.2275, 1.54899979, -3.727593],
#    'size': [1.91178322, 0.820354462, 0.03581524]},
#   'states': []},
#  {'id': 259,
#   'category': 'Decor',
#   'class_name': 'pillow',
#   'bounding_box': {'center': [-14.3879328, 0.531271756, -2.13646746],
#    'size': [0.7523226, 0.202543557, 0.857013345]},
#   'states': []},
#  {'id': 260,
#   'category': 'Decor',
#   'class_name': 'pillow',
#   'bounding_box': {'center': [-14.37087, 0.538728237, -3.092139],
#    'size': [0.7736851, 0.202543631, 0.874123335]},
#   'states': []},
#  {'id': 261,
#   'category': 'Props',
#   'class_name': 'book',
#   'bounding_box': {'center': [-13.8150778, 0.55710274, 0.950611353],
#    'size': [0.330421329, 0.0407823548, 0.290668368]},
#   'states': ['CLOSED']},
#  {'id': 262,
#   'category': 'Props',
#   'class_name': 'book',
#   'bounding_box': {'center': [-12.3195333, 1.63317549, 0.9398098],
#    'size': [0.267383873, 0.030785488, 0.270356059]},
#   'states': ['CLOSED']},
#  {'id': 263,
#   'category': 'Props',
#   'class_name': 'dishbowl',
#   'bounding_box': {'center': [-13.8145, 1.10658348, 0.9434997],
#    'size': [0.273860782, 0.08116754, 0.273860782]},
#   'states': []},
#  {'id': 264,
#   'category': 'Props',
#   'class_name': 'book',
#   'bounding_box': {'center': [-12.3193531, 1.60086155, 0.9398847],
#    'size': [0.2602262, 0.0342060961, 0.28749916]},
#   'states': ['CLOSED']},
#  {'id': 265,
#   'category': 'Props',
#   'class_name': 'book',
#   'bounding_box': {'center': [-13.3444176, 0.5633968, 0.9484104],
#    'size': [0.316235751, 0.04543597, 0.253418416]},
#   'states': ['CLOSED']},
#  {'id': 266,
#   'category': 'Props',
#   'class_name': 'photoframe',
#   'bounding_box': {'center': [-12.2918682, 1.17226326, 0.896919131],
#    'size': [0.174618691, 0.212528437, 0.130021676]},
#   'states': []},
#  {'id': 267,
#   'category': 'Props',
#   'class_name': 'facecream',
#   'bounding_box': {'center': [-12.8185005, 1.08176374, 0.885499954],
#    'size': [0.0645537749, 0.03152771, 0.06455387]},
#   'states': []},
#  {'id': 268,
#   'category': 'Props',
#   'class_name': 'deodorant',
#   'bounding_box': {'center': [-12.8945, 1.13920379, 0.9574998],
#    'size': [0.04111485, 0.1464077, 0.04111537]},
#   'states': []},
#  {'id': 269,
#   'category': 'Props',
#   'class_name': 'perfume',
#   'bounding_box': {'center': [-12.9695, 1.14242268, 0.8804999],
#    'size': [0.0532537177, 0.152845576, 0.0532537177]},
#   'states': []},
#  {'id': 270,
#   'category': 'Props',
#   'class_name': 'box',
#   'bounding_box': {'center': [-13.6685, 2.157594, 0.9345],
#    'size': [0.457236648, 0.119188808, 0.263480037]},
#   'states': ['CLOSED']},
#  {'id': 271,
#   'category': 'Props',
#   'class_name': 'painkillers',
#   'bounding_box': {'center': [-12.7242508, 1.12934339, 0.942275167],
#    'size': [0.09543787, 0.126186147, 0.09495075]},
#   'states': []},
#  {'id': 272,
#   'category': 'Props',
#   'class_name': 'poundcake',
#   'bounding_box': {'center': [-10.7105, 1.01616, -0.9005002],
#    'size': [0.270831317, 0.1003212, 0.270831317]},
#   'states': []},
#  {'id': 274,
#   'category': 'Props',
#   'class_name': 'cellphone',
#   'bounding_box': {'center': [-12.78, 0.5509, 0.8828],
#    'size': [0.176643372, 0.0240000486, 0.14095664]},
#   'states': ['OFF']},
#  {'id': 275,
#   'category': 'Props',
#   'class_name': 'book',
#   'bounding_box': {'center': [-10.873, 0.978431046, -0.2969386],
#    'size': [0.29712677, 0.0470556021, 0.3081826]},
#   'states': ['CLOSED']},
#  {'id': 276,
#   'category': 'Props',
#   'class_name': 'folder',
#   'bounding_box': {'center': [-10.8223724, 1.004, 0.282],
#    'size': [0.281150818, 0.07636905, 0.320075631]},
#   'states': ['CLOSED']},
#  {'id': 277,
#   'category': 'Props',
#   'class_name': 'folder',
#   'bounding_box': {'center': [-10.357, 1.111, 0.215],
#    'size': [0.281497955, 0.319756985, 0.07630986]},
#   'states': ['CLOSED']},
#  {'id': 278,
#   'category': 'Electronics',
#   'class_name': 'lightswitch',
#   'bounding_box': {'center': [-10.0300522, 1.248, -3.1195],
#    'size': [0.005105672, 0.0936371461, 0.06867787]},
#   'states': ['ON']},
#  {'id': 279,
#   'category': 'Electronics',
#   'class_name': 'powersocket',
#   'bounding_box': {'center': [-14.912468, 0.141, 0.4875002],
#    'size': [0.01606408, 0.154280722, 0.09082343]},
#   'states': []},
#  {'id': 280,
#   'category': 'Furniture',
#   'class_name': 'bookshelf',
#   'bounding_box': {'center': [-13.0735, 1.04867315, 0.9375],
#    'size': [1.99890113, 2.09534621, 0.3025775]},
#   'states': ['CLOSED']},
#  {'id': 281,
#   'category': 'Furniture',
#   'class_name': 'desk',
#   'bounding_box': {'center': [-10.6015, 0.475000024, -0.3175],
#    'size': [1.06800008, 0.950000048, 2.028]},
#   'states': ['CLOSED']},
#  {'id': 282,
#   'category': 'Furniture',
#   'class_name': 'nightstand',
#   'bounding_box': {'center': [-14.4675, 0.242000014, -1.08149993],
#    'size': [0.748, 0.484000027, 0.748]},
#   'states': ['CLOSED']},
#  {'id': 283,
#   'category': 'Furniture',
#   'class_name': 'chair',
#   'bounding_box': {'center': [-11.1775007, 0.495000035, -0.299500018],
#    'size': [0.523600042, 0.8415001, 0.401200026]},
#   'states': []},
#  {'id': 284,
#   'category': 'Furniture',
#   'class_name': 'bed',
#   'bounding_box': {'center': [-13.69924, 0.3244711, -2.6705],
#    'size': [2.40117645, 0.6478033, 1.991632]},
#   'states': []},
#  {'id': 285,
#   'category': 'Rooms',
#   'class_name': 'bathroom',
#   'bounding_box': {'center': [1.28179967, 1.25, -3.75999975],
#    'size': [8.0, 3.0, 5.5]},
#   'states': []},
#  {'id': 286,
#   'category': 'Walls',
#   'class_name': 'wall',
#   'bounding_box': {'center': [3.78179765, 1.25, -5.00999928],
#    'size': [2.50000644, 2.500009, 2.500007]},
#   'states': []},
#  {'id': 287,
#   'category': 'Walls',
#   'class_name': 'wall',
#   'bounding_box': {'center': [-1.21820092, 1.25, -5.00999641],
#    'size': [2.50000453, 2.500009, 2.500004]},
#   'states': []},
#  {'id': 288,
#   'category': 'Walls',
#   'class_name': 'wall',
#   'bounding_box': {'center': [-1.218198, 1.25, -2.50999951],
#    'size': [2.50000572, 2.500009, 2.5000062]},
#   'states': []},
#  {'id': 289,
#   'category': 'Walls',
#   'class_name': 'wall',
#   'bounding_box': {'center': [3.78180027, 1.25, -2.51000214],
#    'size': [2.500005, 2.500009, 2.50000453]},
#   'states': []},
#  {'id': 290,
#   'category': 'Walls',
#   'class_name': 'wall',
#   'bounding_box': {'center': [1.28180766, 1.24999344, -6.2300005],
#    'size': [2.50001931, 2.50002646, 0.0600010939]},
#   'states': []},
#  {'id': 291,
# ...
#   'class_name': 'toothbrush',
#   'bounding_box': {'center': [4.86179972, 1.094192, -3.56001544],
#    'size': [0.0165090449, 0.238005, 0.08614795]},
#   'states': []},
#  {'id': 341,
#   'category': 'Props',
#   'class_name': 'barsoap',
#   'bounding_box': {'center': [4.8918, 0.998697, -2.810001],
#    'size': [0.0766216144, 0.0433947556, 0.129800856]},
#   'states': []},
#  {'id': 342,
#   'category': 'Props',
#   'class_name': 'towel',
#   'bounding_box': {'center': [2.95779824, 1.065752, -6.127835],
#    'size': [0.316705763, 0.4129926, 0.0332074948]},
#   'states': []},
#  {'id': 343,
#   'category': 'Props',
#   'class_name': 'towel',
#   'bounding_box': {'center': [3.62379813, 1.065752, -6.127835],
#    'size': [0.316705763, 0.4129926, 0.0332074948]},
#   'states': []},
#  {'id': 344,
#   'category': 'Electronics',
#   'class_name': 'lightswitch',
#   'bounding_box': {'center': [1.8307004, 1.2901, -1.31325173],
#    'size': [0.06867785, 0.0936371461, 0.00510568451]},
#   'states': ['ON']},
#  {'id': 345,
#   'category': 'Appliances',
#   'class_name': 'washingmachine',
#   'bounding_box': {'center': [-0.368201226, 0.499382854, -5.809999],
#    'size': [0.724770069, 0.9977087, 0.66216284]},
#   'states': ['CLOSED', 'OFF']},
#  {'id': 346,
#   'category': 'Rooms',
#   'class_name': 'bedroom',
#   'bounding_box': {'center': [3.75, 1.25, 2.49000025],
#    'size': [8.0, 3.0, 8.0]},
#   'states': []},
#  {'id': 347,
#   'category': 'Floor',
#   'class_name': 'floor',
#   'bounding_box': {'center': [6.25, 0.0, 4.99],
#    'size': [2.5, 9.049975e-06, 2.5]},
#   'states': []},
#  {'id': 348,
#   'category': 'Floor',
#   'class_name': 'floor',
#   'bounding_box': {'center': [6.25, 0.0, 2.49000025],
#    'size': [2.50000048, 9.049975e-06, 2.5]},
#   'states': []},
#  {'id': 349,
#   'category': 'Floor',
#   'class_name': 'floor',
#   'bounding_box': {'center': [6.25, 0.0, -0.009999573],
#    'size': [2.50000048, 9.049975e-06, 2.5]},
#   'states': []},
#  {'id': 350,
#   'category': 'Floor',
#   'class_name': 'floor',
#   'bounding_box': {'center': [3.74999976, 0.0, -0.009999096],
#    'size': [2.50000048, 9.049975e-06, 2.5]},
#   'states': []},
#  {'id': 351,
#   'category': 'Floor',
#   'class_name': 'floor',
#   'bounding_box': {'center': [3.75, 0.0, 2.49000049],
#    'size': [2.5, 9.049975e-06, 2.5]},
#   'states': []},
#  {'id': 352,
#   'category': 'Floor',
#   'class_name': 'floor',
#   'bounding_box': {'center': [3.75000048, 0.0, 4.99000025],
#    'size': [2.5, 9.049975e-06, 2.50000024]},
#   'states': []},
#  {'id': 353,
#   'category': 'Floor',
#   'class_name': 'floor',
#   'bounding_box': {'center': [1.25000072, 0.0, 4.99000072],
#    'size': [2.5, 9.049975e-06, 2.50000024]},
#   'states': []},
#  {'id': 354,
#   'category': 'Floor',
#   'class_name': 'floor',
#   'bounding_box': {'center': [1.25000024, 0.0, 2.490001],
#    'size': [2.5, 9.049975e-06, 2.5]},
#   'states': []},
#  {'id': 355,
#   'category': 'Floor',
#   'class_name': 'floor',
#   'bounding_box': {'center': [1.25000012, 0.0, -0.009999216],
#    'size': [2.49999976, 9.049975e-06, 2.5]},
#   'states': []},
#  {'id': 356,
#   'category': 'Walls',
#   'class_name': 'wall',
#   'bounding_box': {'center': [3.74999666, 1.24999988, 6.20999861],
#    'size': [2.50000882, 2.50000882, 0.06000099]},
#   'states': []},
#  {'id': 357,
#   'category': 'Walls',
#   'class_name': 'wall',
#   'bounding_box': {'center': [3.75000548, 1.24999988, -1.22999692],
#    'size': [2.50000882, 2.50000882, 0.0600012876]},
#   'states': []},
#  {'id': 358,
#   'category': 'Walls',
#   'class_name': 'wall',
#   'bounding_box': {'center': [7.4700017, 1.24999344, 2.49000931],
#    'size': [0.0599976741, 2.50002646, 2.50001764]},
#   'states': []},
#  {'id': 359,
#   'category': 'Walls',
#   'class_name': 'wall',
#   'bounding_box': {'center': [6.249999, 1.25, 4.98999834],
#    'size': [2.500005, 2.500009, 2.50000453]},
#   'states': []},
#  {'id': 360,
#   'category': 'Walls',
#   'class_name': 'wall',
#   'bounding_box': {'center': [6.249998, 1.25, -0.009997964],
#    'size': [2.50000381, 2.500009, 2.50000429]},
#   'states': []},
#  {'id': 361,
#   'category': 'Walls',
#   'class_name': 'wall',
#   'bounding_box': {'center': [1.25000453, 1.25, 4.99],
#    'size': [2.50000334, 2.500009, 2.50000381]},
#   'states': []},
#  {'id': 362,
#   'category': 'Walls',
#   'class_name': 'wall',
#   'bounding_box': {'center': [0.0300010182, 1.24999571, 2.48999643],
#    'size': [0.06000357, 2.50000954, 2.500009]},
#   'states': []},
#  {'id': 363,
#   'category': 'Walls',
#   'class_name': 'wall',
#   'bounding_box': {'center': [1.25000226, 1.2500093, -0.0100123882],
#    'size': [2.49999976, 2.50002766, 2.50004435]},
#   'states': []},
#  {'id': 364,
#   'category': 'Windows',
#   'class_name': 'window',
#   'bounding_box': {'center': [7.499934, 1.50000024, 2.49000144],
#    'size': [0.113748632, 1.02450514, 2.11254787]},
#   'states': ['CLOSED']},
#  {'id': 365,
#   'category': 'Ceiling',
#   'class_name': 'ceiling',
#   'bounding_box': {'center': [6.24999142, 2.50000024, 4.99],
#    'size': [2.50000048, 9.059906e-06, 2.5]},
#   'states': []},
#  {'id': 366,
#   'category': 'Ceiling',
#   'class_name': 'ceiling',
#   'bounding_box': {'center': [6.24999046, 2.50000024, 2.49000025],
#    'size': [2.5, 9.059906e-06, 2.5]},
#   'states': []},
#  {'id': 367,
#   'category': 'Ceiling',
#   'class_name': 'ceiling',
#   'bounding_box': {'center': [6.24999046, 2.50000024, -0.009999573],
#    'size': [2.5, 9.059906e-06, 2.5]},
#   'states': []},
#  {'id': 368,
#   'category': 'Ceiling',
#   'class_name': 'ceiling',
#   'bounding_box': {'center': [3.74999046, 2.50000024, -0.009999096],
#    'size': [2.5, 9.059906e-06, 2.5]},
#   'states': []},
#  {'id': 369,
#   'category': 'Ceiling',
#   'class_name': 'ceiling',
#   'bounding_box': {'center': [3.74999118, 2.50000024, 2.49000049],
#    'size': [2.50000048, 9.059906e-06, 2.5]},
#   'states': []},
#  {'id': 370,
#   'category': 'Ceiling',
#   'class_name': 'ceiling',
#   'bounding_box': {'center': [3.74999142, 2.50000024, 4.99000025],
#    'size': [2.5, 9.059906e-06, 2.50000024]},
#   'states': []},
#  {'id': 371,
#   'category': 'Ceiling',
#   'class_name': 'ceiling',
#   'bounding_box': {'center': [1.24999166, 2.50000024, 4.99000072],
#    'size': [2.5, 9.059906e-06, 2.50000024]},
#   'states': []},
#  {'id': 372,
#   'category': 'Ceiling',
#   'class_name': 'ceiling',
#   'bounding_box': {'center': [1.24999118, 2.50000024, 2.490001],
#    'size': [2.5, 9.059906e-06, 2.5]},
#   'states': []},
#  {'id': 373,
#   'category': 'Ceiling',
#   'class_name': 'ceiling',
#   'bounding_box': {'center': [1.24999118, 2.50000024, -0.009999096],
#    'size': [2.5, 9.059906e-06, 2.5]},
#   'states': []},
#  {'id': 374,
#   'category': 'Doors',
#   'class_name': 'doorjamb',
#   'bounding_box': {'center': [0.0003574714, 1.029126, 2.489997],
#    'size': [0.122323029, 2.058256, 0.9283974]},
#   'states': []},
#  {'id': 375,
#   'category': 'Lamps',
#   'class_name': 'ceilinglamp',
#   'bounding_box': {'center': [3.750001, 2.22767544, 2.49000072],
#    'size': [0.5316591, 0.5451052, 0.5316591]},
#   'states': []},
#  {'id': 376,
#   'category': 'Lamps',
#   'class_name': 'tablelamp',
#   'bounding_box': {'center': [7.00300026, 0.8004272, 3.94299984],
#    'size': [0.3439865, 0.577501535, 0.355349541]},
#   'states': ['ON']},
#  {'id': 377,
#   'category': 'Lamps',
#   'class_name': 'tablelamp',
#   'bounding_box': {'center': [7.05199957, 0.7744272, 1.61600089],
#    'size': [0.316288, 0.577501357, 0.33128]},
#   'states': ['ON']},
#  {'id': 379,
#   'category': 'Props',
#   'class_name': 'photoframe',
#   'bounding_box': {'center': [5.340783, 1.77626324, -0.958484948],
#    'size': [0.175086528, 0.212528616, 0.140783221]},
#   'states': []},
#  {'id': 380,
#   'category': 'Props',
#   'class_name': 'book',
#   'bounding_box': {'center': [4.43513727, 1.1523968, -1.07050776],
#    'size': [0.38165766, 0.04543643, 0.3452789]},
#   'states': ['CLOSED']},
#  {'id': 381,
#   'category': 'Props',
#   'class_name': 'book',
#   'bounding_box': {'center': [5.1263833, 1.24601364, -0.9755474],
#    'size': [0.0889190137, 0.236889824, 0.187510908]},
#   'states': ['CLOSED']},
#  {'id': 382,
#   'category': 'Props',
#   'class_name': 'box',
#   'bounding_box': {'center': [5.44, 0.667310238, -1.08399773],
#    'size': [0.405635744, 0.194623411, 0.279948473]},
#   'states': ['CLOSED']},
#  {'id': 384,
#   'category': 'Props',
#   'class_name': 'mug',
#   'bounding_box': {'center': [0.7999811, 1.00468671, 0.196181774],
#    'size': [0.134328142, 0.0995673, 0.148728982]},
#   'states': []},
#  {'id': 385,
#   'category': 'Props',
#   'class_name': 'cupcake',
#   'bounding_box': {'center': [0.336001724, 1.0101856, 0.260001183],
#    'size': [0.09984727, 0.09922324, 0.09988424]},
#   'states': []},
#  {'id': 386,
#   'category': 'Props',
#   'class_name': 'pillow',
#   'bounding_box': {'center': [6.971459, 0.5643889, 2.84203458],
#    'size': [0.752261937, 0.202543557, 0.8569646]},
#   'states': []},
#  {'id': 387,
#   'category': 'Props',
#   'class_name': 'toy',
#   'bounding_box': {'center': [5.94710875, 1.21403551, -1.0602591],
#    'size': [0.2662115, 0.14548707, 0.2536645]},
#   'states': []},
#  {'id': 388,
#   'category': 'Props',
#   'class_name': 'pillow',
#   'bounding_box': {'center': [6.936482, 0.568114, 3.52557278],
#    'size': [0.7737438, 0.20254378, 0.874170661]},
#   'states': []},
#  {'id': 389,
#   'category': 'Props',
#   'class_name': 'remotecontrol',
#   'bounding_box': {'center': [5.453932, 1.1413, -1.00177455],
#    'size': [0.0659999847, 0.0299999714, 0.22299999]},
#   'states': ['OFF']},
#  {'id': 390,
#   'category': 'Furniture',
#   'class_name': 'bookshelf',
#   'bounding_box': {'center': [5.17999935, 1.108, -1.06099772],
#    'size': [2.11399937, 2.216, 0.320000172]},
#   'states': ['CLOSED']},
#  {'id': 391,
#   'category': 'Furniture',
#   'class_name': 'nightstand',
#   'bounding_box': {'center': [7.14999962, 0.242000014, 1.58200145],
#    'size': [0.747999966, 0.484000027, 0.748]},
#   'states': ['CLOSED']},
#  {'id': 392,
#   'category': 'Furniture',
#   'class_name': 'chair',
#   'bounding_box': {'center': [1.83144093, 0.781, 1.064081],
#    'size': [0.695325732, 1.3277, 0.5605763]},
#   'states': []},
#  {'id': 393,
#   'category': 'Furniture',
#   'class_name': 'desk',
#   'bounding_box': {'center': [0.5000019, 0.475000024, 0.9300029],
#    'size': [1.068, 0.950000048, 2.02799988]},
#   'states': ['CLOSED']},
#  {'id': 394,
#   'category': 'Furniture',
#   'class_name': 'bed',
#   'bounding_box': {'center': [6.20974064, 0.3474711, 3.14000034],
#    'size': [2.4010067, 0.647803366, 1.99171925]},
#   'states': []},
#  {'id': 395,
#   'category': 'Furniture',
#   'class_name': 'closet',
#   'bounding_box': {'center': [3.74999881, 0.99999994, 5.918971],
#    'size': [2.00013351, 2.00001431, 0.5089429]},
#   'states': ['CLOSED']},
#  {'id': 396,
#   'category': 'Furniture',
#   'class_name': 'cabinet',
#   'bounding_box': {'center': [1.459403, 0.5249999, 5.95199871],
#    'size': [1.17999935, 1.04999983, 0.379999876]},
#   'states': ['CLOSED']},
#  {'id': 397,
#   'category': 'Electronics',
#   'class_name': 'computer',
#   'bounding_box': {'center': [0.6250037, 0.367990226, 0.290001154],
#    'size': [0.7459847, 0.7359814, 0.258682162]},
#   'states': ['OFF']},
#  {'id': 398,
#   'category': 'Electronics',
#   'class_name': 'mouse',
#   'bounding_box': {'center': [0.740001738, 0.984096766, 1.55000222],
#    'size': [0.208997354, 0.0402507074, 0.172031417]},
#   'states': []},
#  {'id': 399,
#   'category': 'Electronics',
#   'class_name': 'mousemat',
#   'bounding_box': {'center': [0.700002968, 0.9584852, 1.54000139],
#    'size': [0.4324621, 0.00716543244, 0.436930418]},
#   'states': []},
#  {'id': 400,
#   'category': 'Electronics',
#   'class_name': 'keyboard',
#   'bounding_box': {'center': [0.8000022, 0.9795669, 0.8250023],
#    'size': [0.221636087, 0.04913636, 0.7071991]},
#   'states': []},
#  {'id': 401,
#   'category': 'Electronics',
#   'class_name': 'cpuscreen',
#   'bounding_box': {'center': [0.5156917, 1.2938025, 0.9300003],
#    'size': [0.288627982, 0.6776071, 0.9265996]},
#   'states': []},
#  {'id': 402,
#   'category': 'Electronics',
#   'class_name': 'lightswitch',
#   'bounding_box': {'center': [0.0525546074, 1.204, 3.09800053],
#    'size': [0.005106009, 0.09363716, 0.06867785]},
#   'states': ['ON']},
#  {'id': 403,
#   'category': 'Electronics',
#   'class_name': 'radio',
#   'bounding_box': {'center': [1.43477726, 1.18581784, 5.93967247],
#    'size': [0.5783105, 0.274262667, 0.354999542]},
#   'states': ['OFF']},
#  {'id': 404,
#   'category': 'Decor',
#   'class_name': 'rug',
#   'bounding_box': {'center': [5.9530015, 0.0122674955, 2.49000025],
#    'size': [2.95486164, 0.024545474, 3.84983253]},
#   'states': []},
#  {'id': 405,
#   'category': 'Decor',
#   'class_name': 'wallpictureframe',
#   'bounding_box': {'center': [0.0741276741, 1.24999964, 4.720001],
#    'size': [0.0482597649, 1.10530066, 2.57583141]},
#   'states': []},
#  {'id': 406,
#   'category': 'Decor',
#   'class_name': 'wallpictureframe',
#   'bounding_box': {'center': [6.124999, 1.25000012, 6.16813946],
#    'size': [0.955625534, 1.25704026, 0.04172325]},
#   'states': []},
#  {'id': 407,
#   'category': 'Decor',
#   'class_name': 'wallpictureframe',
#   'bounding_box': {'center': [7.417139, 1.40400016, 0.23000133],
#    'size': [0.041721344, 1.2570436, 0.9556304]},
#   'states': []},
#  {'id': 408,
#   'category': 'Decor',
#   'class_name': 'curtains',
#   'bounding_box': {'center': [7.40856075, 2.01888561, 2.489883],
#    'size': [0.0259938221, 0.0333948135, 2.328011]},
#   'states': ['CLOSED']},
#  {'id': 409,
#   'category': 'Decor',
#   'class_name': 'curtains',
#   'bounding_box': {'center': [7.37901, 1.45854831, 3.20600939],
#    'size': [0.107337952, 1.15232611, 0.5931845]},
#   'states': ['CLOSED']},
#  {'id': 410,
#   'category': 'Decor',
#   'class_name': 'curtains',
#   'bounding_box': {'center': [7.37900829, 1.45854843, 1.79399824],
#    'size': [0.107337475, 1.15232587, 0.593184]},
#   'states': ['CLOSED']},
#  {'id': 411,
#   'category': 'PRE_PRO_Plate_01',
#   'class_name': 'plate',
#   'bounding_box': {'center': [-7.05699968, 0.8476115, 1.372],
#    'size': [0.290419757, 0.0192230251, 0.290419757]},
#   'states': []},
#  {'id': 412,
#   'category': 'PRE_PRO_Plate_01',
#   'class_name': 'plate',
#   'bounding_box': {'center': [-7.076813, 0.9776342, 7.39342833],
#    'size': [0.290419757, 0.0192230251, 0.290419757]},
#   'states': []},
#  {'id': 413,
#   'category': 'PRE_PRO_Plate_01',
#   'class_name': 'plate',
#   'bounding_box': {'center': [-7.23842335, 2.18311143, 1.7428],
#    'size': [0.290419757, 0.0192230251, 0.290419757]},
#   'states': []},
#  {'id': 414,
#   'category': 'PRE_PRO_Wine_glass_01 1',
#   'class_name': 'wineglass',
#   'bounding_box': {'center': [-7.054, 1.16508579, 5.404],
#    'size': [0.08954637, 0.190210134, 0.089546375]},
#   'states': []},
#  {'id': 415,
#   'category': 'PRE_PRO_Wine_glass_01 1',
#   'class_name': 'wineglass',
#   'bounding_box': {'center': [-6.86100054, 1.16637981, -0.311000019],
#    'size': [0.08954637, 0.190210134, 0.089546375]},
#   'states': []},
#  {'id': 416,
#   'category': 'PRE_PRO_Fork_01',
#   'class_name': 'cutleryfork',
#   'bounding_box': {'center': [-7.054, 1.15458548, 5.904],
#    'size': [0.26143527, 0.0193981566, 0.0257531479]},
#   'states': []},
#  {'id': 417,
#   'category': 'PRE_PRO_Fork_01',
#   'class_name': 'cutleryfork',
#   'bounding_box': {'center': [-6.93944263, 0.9476991, 1.53380334],
#    'size': [0.26143527, 0.0193981566, 0.0257531479]},
#   'states': []},
#  {'id': 418,
#   'category': 'PRE_PRO_Fork_01',
#   'class_name': 'cutleryfork',
#   'bounding_box': {'center': [-6.7756834, 1.18097389, -0.218294919],
#    'size': [0.26143527, 0.0193981566, 0.0257531479]},
#   'states': []},
#  {'id': 419,
#   'category': 'PRE_PRO_Water_glass_01',
#   'class_name': 'waterglass',
#   'bounding_box': {'center': [-7.35871744, 0.450940728, -4.473367],
#    'size': [0.08951233, 0.123450167, 0.08951233]},
#   'states': []},
#  {'id': 420,
#   'category': 'PRE_PRO_Water_glass_01',
#   'class_name': 'waterglass',
#   'bounding_box': {'center': [-7.25871754, 0.450907558, -4.473367],
#    'size': [0.08951233, 0.123450167, 0.08951233]},
#   'states': []},
#  {'id': 421,
#   'category': 'PRE_PRO_Water_glass_01',
#   'class_name': 'waterglass',
#   'bounding_box': {'center': [1.45940268, 0.8363316, 5.951999],
#    'size': [0.08951233, 0.123450167, 0.08951233]},
#   'states': []},
#  {'id': 422,
#   'category': 'PRE_PRO_Wine_glass_01 1',
#   'class_name': 'wineglass',
#   'bounding_box': {'center': [1.45940256, 0.8697116, 5.951999],
#    'size': [0.089546375, 0.190210134, 0.08954637]},
#   'states': []}]

# %%
data_info['../../data_scratch/train_env_task_set_20_full_reduced_tasks/6_partial_opencost0_closecostFalse_walkcost0.05_forgetrate0.2v9_particles_v2/logs_episode.305_iter.0.pik'].keys()
# Out:
# dict_keys(['length', 'script', 'finished', 'total'])

# %%
import ipdb
total, cont = 0, 0
for prog in agent_files['1_full_opencost0_closecostFalse_walkcost0.05_forgetrate0v9_particles_v2']:
    script = data_info[prog]['script'][0]
    grab = len([x for x in script if 'grab' in x])
    put = len([x for x in script if 'put' in x])
    if grab != put:
        cont += 1
#         for p in script:
#             print(p)
#         ipdb.set_trace()
    total += 1

# %%
script = data_info[prog]['script']

# %%
data_info[list(data_info.keys())[0]]
# Out:
# {'length': 41,
#  'script': {0: ['[walktowards] <kitchencabinet> (137)',
#    '[walktowards] <kitchencabinet> (137)',
#    '[walktowards] <kitchencabinet> (137)',
#    '[walktowards] <kitchencabinet> (137)',
#    '[walktowards] <kitchencabinet> (137)',
#    '[walktowards] <kitchencabinet> (137)',
#    '[walktowards] <kitchencabinet> (137)',
#    '[open] <kitchencabinet> (137)',
#    '[grab] <cutleryfork> (388)',
#    '[grab] <cutleryfork> (386)',
#    '[walktowards] <kitchentable> (132)',
#    '[walktowards] <kitchentable> (132)',
#    '[putback] <cutleryfork> (388) <kitchentable> (132)',
#    '[walktowards] <kitchencabinet> (139)',
#    '[walktowards] <kitchencabinet> (139)',
#    '[walktowards] <kitchencabinet> (139)',
#    '[walktowards] <kitchencabinet> (139)',
#    '[open] <kitchencabinet> (139)',
#    '[walktowards] <kitchentable> (132)',
#    '[walktowards] <kitchentable> (132)',
#    '[walktowards] <cutleryfork> (387)',
#    '[walktowards] <kitchentable> (132)',
#    '[walktowards] <kitchentable> (132)',
#    '[walktowards] <cutleryfork> (387)',
#    '[walktowards] <cutleryfork> (387)',
#    '[walktowards] <kitchentable> (132)',
#    '[walktowards] <kitchentable> (132)',
#    '[walktowards] <cutleryfork> (387)',
#    '[walktowards] <cutleryfork> (387)',
#    '[walktowards] <kitchentable> (132)',
#    '[walktowards] <kitchentable> (132)',
#    '[walktowards] <cutleryfork> (387)',
#    '[walktowards] <cutleryfork> (387)',
#    '[walktowards] <kitchentable> (132)',
#    '[walktowards] <kitchentable> (132)',
#    '[walktowards] <cutleryfork> (387)',
#    '[walktowards] <cutleryfork> (387)',
#    '[grab] <cutleryfork> (387)',
#    '[walktowards] <kitchentable> (132)',
#    '[walktowards] <kitchentable> (132)',
#    '[putback] <cutleryfork> (386) <kitchentable> (132)'],
#   1: []},
#  'finished': 2,
#  'total': 2}

# %%
total
# Out:
# 316

# %%
import pickle as pkl
with open('../dataset/test_env_task_set_10_full_reduced_tasks_single.pik', 'rb') as f:
    init_dataset = pkl.load(f)

# %%
for it, file in enumerate(init_dataset):
    goal = [x for x, y in file['task_goal'][0].items() if y > 0][0]
    goal_name = goal.split('_')[1]
    locs = []
    id2node = {node['id']: node for node in file['init_graph']['nodes']}
    dict_goal = {}
    for node in file['init_graph']['nodes']:
        if node['class_name'] == goal_name:
            dict_goal[node['id']] = ['', '', '']
    for edge in file['init_graph']['edges']:
        if edge['relation_type'].lower() not in  ['facing', 'close'] and edge['from_id'] in dict_goal:
            to_id = edge['to_id']
            from_id = edge['from_id']
            if id2node[to_id]['category'] == 'Rooms':
                dict_goal[from_id][1] = id2node[to_id]['class_name']
            else:
                dict_goal[from_id][0] = id2node[to_id]['class_name']
                dict_goal[from_id][2] = edge['relation_type']
    
    init_room = file['init_rooms'][0]
    locations = ', '.join(['{} {} ()'.format(gv[2], gv[0], gv[1]) for gv in dict_goal.values()])
    print('File {}. Init Room: {}. Goal {}: {}'.format(it, init_room, goal_name, locations))
#     print('-----')
# Out:
# File 0. Init Room: livingroom. Goal wineglass: INSIDE kitchencabinet (), INSIDE cabinet ()
# File 1. Init Room: bathroom. Goal waterglass: ON coffeetable ()
# File 2. Init Room: kitchen. Goal waterglass: INSIDE kitchencabinet ()
# File 3. Init Room: kitchen. Goal plate: ON kitchencounter (), ON sink (), ON kitchencounter ()
# File 4. Init Room: kitchen. Goal cutleryfork: ON kitchencounter (), INSIDE kitchencabinet (), INSIDE kitchencabinet ()
# File 5. Init Room: kitchen. Goal cutleryfork: INSIDE kitchencabinet (), INSIDE kitchencabinet ()
# File 6. Init Room: bathroom. Goal waterglass: INSIDE cabinet ()
# File 7. Init Room: livingroom. Goal waterglass: ON kitchencounter (), ON kitchencounter ()
# File 8. Init Room: kitchen. Goal cutleryfork:   (), ON kitchencounter (),   ()
# File 9. Init Room: bathroom. Goal waterglass: INSIDE cabinet ()
# File 10. Init Room: kitchen. Goal waterglass: ON kitchencounter (), ON coffeetable ()
# File 11. Init Room: bathroom. Goal wineglass: INSIDE dishwasher (), INSIDE dishwasher ()
# File 12. Init Room: bedroom. Goal wineglass: INSIDE kitchencabinet (), INSIDE kitchencabinet (), ON coffeetable ()
# File 13. Init Room: kitchen. Goal cutleryfork: INSIDE kitchencabinet (), INSIDE dishwasher (), ON sink ()
# File 14. Init Room: kitchen. Goal plate: INSIDE dishwasher ()
# File 15. Init Room: bathroom. Goal wineglass: INSIDE cabinet ()
# File 16. Init Room: kitchen. Goal cutleryfork: ON kitchencounter (), INSIDE kitchencabinet (), INSIDE kitchencabinet ()
# File 17. Init Room: livingroom. Goal wineglass: INSIDE dishwasher (), INSIDE dishwasher ()
# File 18. Init Room: bathroom. Goal waterglass: INSIDE kitchencabinet (), INSIDE cabinet ()
# File 19. Init Room: bedroom. Goal cutleryfork: INSIDE dishwasher (), INSIDE kitchencabinet ()
# File 20. Init Room: bedroom. Goal cupcake: INSIDE microwave (), ON kitchentable ()
# File 21. Init Room: livingroom. Goal pudding: ON coffeetable (), ON coffeetable ()
# File 22. Init Room: kitchen. Goal wine: ON kitchentable (), INSIDE kitchencabinet ()
# File 23. Init Room: kitchen. Goal pancake: ON kitchencounter (), INSIDE cabinet ()
# File 24. Init Room: bathroom. Goal wine: ON kitchencounter ()
# File 25. Init Room: livingroom. Goal cupcake: INSIDE microwave (), ON kitchentable ()
# File 26. Init Room: bathroom. Goal pancake: ON kitchentable ()
# File 27. Init Room: bathroom. Goal pudding: ON kitchentable ()
# File 28. Init Room: livingroom. Goal pancake: ON kitchentable (), ON kitchentable ()
# File 29. Init Room: livingroom. Goal cupcake: ON kitchentable ()
# File 30. Init Room: livingroom. Goal pancake: INSIDE stove (), INSIDE cabinet ()
# File 31. Init Room: bathroom. Goal wine: ON kitchentable (), ON kitchentable ()
# File 32. Init Room: livingroom. Goal cupcake: INSIDE fridge (), ON sink ()
# File 33. Init Room: kitchen. Goal pancake: INSIDE fridge ()
# File 34. Init Room: livingroom. Goal apple: INSIDE fridge (), INSIDE kitchencabinet (), INSIDE fridge ()
# File 35. Init Room: kitchen. Goal cupcake: INSIDE stove (), INSIDE cabinet (), INSIDE cabinet ()
# File 36. Init Room: livingroom. Goal wine: ON kitchencounter (), INSIDE cabinet ()
# File 37. Init Room: bathroom. Goal cupcake: INSIDE cabinet (), INSIDE cabinet ()
# File 38. Init Room: kitchen. Goal cupcake: INSIDE stove (), INSIDE microwave ()
# File 39. Init Room: livingroom. Goal poundcake: ON sink ()
# File 40. Init Room: bathroom. Goal pancake: ON kitchencounter ()
# File 41. Init Room: bathroom. Goal apple: INSIDE fridge (), ON kitchencounter (), INSIDE kitchencabinet ()
# File 42. Init Room: bedroom. Goal poundcake: INSIDE stove ()
# File 43. Init Room: bathroom. Goal juice: INSIDE kitchencabinet ()
# File 44. Init Room: kitchen. Goal pancake: INSIDE cabinet ()
# File 45. Init Room: bedroom. Goal apple: INSIDE fridge (), ON kitchencounter (), INSIDE fridge ()
# File 46. Init Room: bedroom. Goal apple: INSIDE fridge (), INSIDE fridge ()
# File 47. Init Room: livingroom. Goal apple: INSIDE kitchencabinet (), ON kitchencounter ()
# File 48. Init Room: bathroom. Goal pancake: ON kitchencounter ()
# File 49. Init Room: bedroom. Goal pudding: INSIDE fridge (), INSIDE fridge (), ON coffeetable ()
# File 50. Init Room: bathroom. Goal juice: INSIDE kitchencabinet (), INSIDE fridge ()
# File 51. Init Room: bathroom. Goal coffeepot: ON kitchencounter (), INSIDE cabinet ()
# File 52. Init Room: bedroom. Goal pancake: INSIDE stove (), INSIDE cabinet ()
# File 53. Init Room: kitchen. Goal pudding: ON coffeetable (), ON coffeetable (), ON coffeetable ()
# File 54. Init Room: kitchen. Goal apple: INSIDE kitchencabinet ()
# File 55. Init Room: livingroom. Goal wine: INSIDE fridge (), INSIDE kitchencabinet ()
# File 56. Init Room: kitchen. Goal pudding: INSIDE fridge (), ON coffeetable ()
# File 57. Init Room: livingroom. Goal juice: ON kitchencounter ()
# File 58. Init Room: bedroom. Goal apple: INSIDE fridge (), INSIDE fridge ()
# File 59. Init Room: bedroom. Goal cupcake: INSIDE microwave ()
# File 60. Init Room: kitchen. Goal waterglass: ON kitchentable ()
# File 61. Init Room: kitchen. Goal cutleryfork: ON kitchencounter (), ON kitchentable (),   ()
# File 62. Init Room: bathroom. Goal wineglass: INSIDE kitchencabinet (), INSIDE cabinet (), ON coffeetable ()
# File 63. Init Room: bedroom. Goal wineglass: INSIDE kitchencabinet (), ON kitchencounter (), ON coffeetable ()
# File 64. Init Room: livingroom. Goal wineglass: ON kitchentable (), INSIDE kitchencabinet (), ON kitchentable ()
# File 65. Init Room: livingroom. Goal waterglass: ON coffeetable (), ON coffeetable ()
# File 66. Init Room: kitchen. Goal plate: INSIDE microwave ()
# File 67. Init Room: kitchen. Goal wineglass: INSIDE kitchencabinet (), INSIDE cabinet ()
# File 68. Init Room: kitchen. Goal plate: ON kitchentable (), INSIDE cabinet (), ON coffeetable ()
# File 69. Init Room: bathroom. Goal cutleryfork: INSIDE kitchencabinet (), INSIDE kitchencabinet (), ON kitchentable ()
# File 70. Init Room: bathroom. Goal cutleryfork: INSIDE kitchencabinet (), INSIDE kitchencabinet ()
# File 71. Init Room: livingroom. Goal waterglass: ON sink (), ON sink ()
# File 72. Init Room: bedroom. Goal plate: INSIDE kitchencabinet (), INSIDE stove (), INSIDE cabinet ()
# File 73. Init Room: livingroom. Goal wineglass: ON kitchentable (), INSIDE kitchencabinet ()
# File 74. Init Room: bedroom. Goal waterglass: ON kitchentable (), ON coffeetable (), ON coffeetable ()
# File 75. Init Room: bathroom. Goal wineglass: INSIDE kitchencabinet (), INSIDE kitchencabinet ()
# File 76. Init Room: bathroom. Goal cutleryfork: INSIDE kitchencabinet ()
# File 77. Init Room: kitchen. Goal waterglass: INSIDE kitchencabinet (), INSIDE cabinet (), INSIDE cabinet ()
# File 78. Init Room: kitchen. Goal cutleryfork: INSIDE kitchencabinet (), INSIDE kitchencabinet ()
# File 79. Init Room: livingroom. Goal plate: INSIDE stove (), INSIDE fridge (), INSIDE fridge ()
# File 80. Init Room: kitchen. Goal cupcake: INSIDE stove (), INSIDE stove (), INSIDE fridge ()
# File 81. Init Room: livingroom. Goal pudding: ON kitchentable (), INSIDE fridge (), ON kitchentable ()
# File 82. Init Room: livingroom. Goal cupcake: INSIDE fridge (), ON kitchencounter (), ON kitchentable ()
# File 83. Init Room: bathroom. Goal book: ON kitchentable (), ON kitchentable (), INSIDE cabinet ()
# File 84. Init Room: bathroom. Goal book: INSIDE cabinet ()
# File 85. Init Room: bathroom. Goal pudding: INSIDE fridge (), ON kitchentable (), INSIDE fridge ()
# File 86. Init Room: kitchen. Goal apple: INSIDE kitchencabinet (), ON sink (), INSIDE kitchencabinet ()
# File 87. Init Room: bathroom. Goal cupcake: INSIDE stove (), ON kitchencounter ()
# File 88. Init Room: bathroom. Goal cupcake: INSIDE cabinet ()
# File 89. Init Room: bedroom. Goal pudding: INSIDE fridge (), ON kitchentable ()
# File 90. Init Room: bedroom. Goal book: INSIDE cabinet ()
# File 91. Init Room: livingroom. Goal book: ON kitchentable (), ON kitchentable (), INSIDE cabinet (), INSIDE cabinet ()
# File 92. Init Room: bedroom. Goal book: INSIDE cabinet (), INSIDE cabinet ()
# File 93. Init Room: livingroom. Goal wine: INSIDE fridge (), ON coffeetable ()
# File 94. Init Room: livingroom. Goal wine: ON kitchentable ()
# File 95. Init Room: bathroom. Goal book: ON kitchentable (), ON kitchentable (), INSIDE cabinet ()
# File 96. Init Room: kitchen. Goal cupcake: ON kitchentable (), INSIDE microwave (), INSIDE fridge ()
# File 97. Init Room: bathroom. Goal pudding: INSIDE fridge (), INSIDE fridge ()
# File 98. Init Room: kitchen. Goal cupcake: ON sink (), INSIDE fridge (), INSIDE stove ()
# File 99. Init Room: bedroom. Goal wine: INSIDE kitchencabinet ()

# %%
[node for node in file['init_graph']['nodes'] if node['class_name'] == 'kitchen']
# Out:
# [{'id': 58,
#   'category': 'Rooms',
#   'class_name': 'kitchen',
#   'prefab_name': 'PRE_ROO_Kitchen_02',
#   'obj_transform': {'position': [-3.75, 0.0, 6.25],
#    'rotation': [0.0, -0.7071068, 0.0, 0.7071067]},
#   'bounding_box': {'center': [-6.249999, 1.25, 2.5], 'size': [8.0, 3.0, 8.0]},
#   'properties': [],
#   'states': []}]

# %%
ls ../../data_scratch/large_data_toy/test_env_task_set_10_full_reduced_tasks_single/*
# Out:
# logs_episode.73_iter.0.pik  logs_episode.78_iter.0.pik

# %%
import glob
import os
def read_file(file_name):
    with open(file_name, 'rb') as f:
        content = pkl.load(f)
    print(len(content['obs']), len(content['action'][0]))
    return '\n'.join(content['action'][0])

root_dir = '../../data_scratch/large_data_toy/test_env_task_set_10_full_reduced_tasks/'
files = ['logs_episode.2_iter.0.pik', 'logs_episode.91_iter.0.pik', 'logs_episode.20_iter.0.pik'] # User for second example
files = ['logs_episode.0_iter.0.pik'] # User for first example
agents = glob.glob('{}/*'.format(root_dir))
for agent in sorted(agents):
    file_name = '{}/{}'.format(agent, files[0])
    if os.path.isfile(file_name):
        content = read_file(file_name)
        print(agent)
        print(content)
# Out:
# 38 37
# ../../data_scratch/large_data_toy/test_env_task_set_10_full_reduced_tasks/1_full_opencost0_closecostFalse_walkcost0.05_forgetrate0v9_particles_v2
# [walktowards] <plate> (374)
# [walktowards] <plate> (374)
# [walktowards] <plate> (374)
# [grab] <plate> (374)
# [walktowards] <bedroom> (210)
# [walktowards] <bedroom> (210)
# [walktowards] <bedroom> (210)
# [walktowards] <bedroom> (210)
# [walktowards] <bedroom> (210)
# [walktowards] <bedroom> (210)
# [open] <cabinet> (216)
# [grab] <plate> (372)
# [walktowards] <kitchen> (11)
# [walktowards] <kitchen> (11)
# [walktowards] <kitchen> (11)
# [walktowards] <kitchen> (11)
# [walktowards] <kitchentable> (72)
# [walktowards] <kitchentable> (72)
# [walktowards] <kitchentable> (72)
# [putback] <plate> (372) <kitchentable> (72)
# [putback] <plate> (374) <kitchentable> (72)
# [walktowards] <kitchencabinet> (77)
# [walktowards] <kitchencabinet> (77)
# [walktowards] <kitchencabinet> (77)
# [open] <kitchencabinet> (77)
# [grab] <wineglass> (369)
# [walktowards] <cutleryfork> (370)
# [walktowards] <cutleryfork> (370)
# [walktowards] <cutleryfork> (370)
# [walktowards] <cutleryfork> (370)
# [walktowards] <cutleryfork> (370)
# [walktowards] <cutleryfork> (370)
# [grab] <cutleryfork> (370)
# [walktowards] <kitchentable> (72)
# [walktowards] <kitchentable> (72)
# [putback] <cutleryfork> (370) <kitchentable> (72)
# [putback] <wineglass> (369) <kitchentable> (72)

# %%
! rm -rf ../../data_scratch/large_data_toy/test_env_task_set_10_full_reduced_tasks_single/7_partial_opencost-500_closecostFalse_walkcost0.01_forgetrate0.01v9_particles_v2
